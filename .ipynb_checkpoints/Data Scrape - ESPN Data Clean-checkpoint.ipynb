# %%
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup

# %%
url = "http://www.espn.com/mlb/freeagents/_/year/2017/type/dollars"
response = requests.get(url)
page = response.text

# %%
soup = BeautifulSoup(page,"html5lib")

# %%
#Players are both in class oddrow and even row
#Using regex to grab both at once
rowplayer_regex = re.compile('.*row\splayer.*')

# %%
col_name_all = soup.find_all(class_="colhead")[1]
col_names_list=[]
for name in col_name_all.find_all("td"):
    col_names_list.append(name.text)

# %% [markdown]
# ## Now Lets Build a List of 2017 MLB Free Agents

# %%
free_agents_list = soup.find_all(class_=rowplayer_regex)

# %%
free_agents_17 = {} #empty dict to add player and his data to
for row in free_agents_list:
    items = row.find_all('td')
    player = items[0].find('a').text
    free_agents_17[player] = [i.text for i in items[1:]]

# %%
free_agents_17df = pd.DataFrame.from_dict\
(data=free_agents_17,orient='index')
free_agents_17df.reset_index(inplace=True)
#reset index because player name shouldn't be index
#We'll need it to join on

# %%
free_agents_17df.head()
# Out:
#            index   0   1       2             3         4  5  6             7
# 0    Eric Hosmer  1B  28  Signed        Royals    Padres  8  7  $144,000,000
# 1     Yu Darvish  SP  31  Signed       Dodgers      Cubs  6  1  $126,000,000
# 2  J.D. Martinez  RF  30  Signed  Diamondbacks   Red Sox  5  6  $110,000,000
# 3   Lorenzo Cain  CF  32  Signed        Royals   Brewers  5  2   $80,000,000
# 4   Jake Arrieta  SP  32  Signed          Cubs  Phillies  3  4   $75,000,000

# %%
#Rename Columns to match ESPN's
col_names_dict = {"index":"PLAYER",0:"POS",1:"AGE",2:"STATUS",\
                 3:"OLD_TEAM",4:"NEW_TEAM",5:"YRS",6:"RK"\
                  ,7:"DOLLARS"}

# %%
free_agents_17df.rename(columns=col_names_dict,inplace=True)

# %%
#Last Step - Add Free Agent Year as Column
free_agents_17df["PLAYER_YEAR"]=free_agents_17df["PLAYER"] + " 2017"

# %%
free_agents_17df.head()
# Out:
#           PLAYER POS AGE  STATUS      OLD_TEAM  NEW_TEAM YRS RK       DOLLARS  \
# 0    Eric Hosmer  1B  28  Signed        Royals    Padres   8  7  $144,000,000
# 1     Yu Darvish  SP  31  Signed       Dodgers      Cubs   6  1  $126,000,000
# 2  J.D. Martinez  RF  30  Signed  Diamondbacks   Red Sox   5  6  $110,000,000
# 3   Lorenzo Cain  CF  32  Signed        Royals   Brewers   5  2   $80,000,000
# 4   Jake Arrieta  SP  32  Signed          Cubs  Phillies   3  4   $75,000,000
#
#           PLAYER_YEAR
# 0    Eric Hosmer 2017
# 1     Yu Darvish 2017
# 2  J.D. Martinez 2017
# 3   Lorenzo Cain 2017
# 4   Jake Arrieta 2017

# %%
#Clean Up DOLLARS column from dashes, commas and $ signs

free_agents_17df["DOLLARS"] = free_agents_17df["DOLLARS"].str.replace(r'\D','0')

free_agents_17df.head()
# Out:
#           PLAYER POS AGE  STATUS      OLD_TEAM  NEW_TEAM YRS RK       DOLLARS  \
# 0    Eric Hosmer  1B  28  Signed        Royals    Padres   8  7  014400000000
# 1     Yu Darvish  SP  31  Signed       Dodgers      Cubs   6  1  012600000000
# 2  J.D. Martinez  RF  30  Signed  Diamondbacks   Red Sox   5  6  011000000000
# 3   Lorenzo Cain  CF  32  Signed        Royals   Brewers   5  2   08000000000
# 4   Jake Arrieta  SP  32  Signed          Cubs  Phillies   3  4   07500000000
#
#   FA_YEAR
# 0    2017
# 1    2017
# 2    2017
# 3    2017
# 4    2017

# %%
#Convert Numeric columns to numbers

num_cols = ["DOLLARS","AGE","YRS","FA_YEAR"]
for col in num_cols:
    free_agents_17df[col]=\
    pd.to_numeric(free_agents_17df[col])

# %%
free_agents_17df.dtypes
# Out:
# PLAYER       object
# POS          object
# AGE           int64
# STATUS       object
# OLD_TEAM     object
# NEW_TEAM     object
# YRS         float64
# RK           object
# DOLLARS       int64
# FA_YEAR       int64
# dtype: object

# %% [markdown]
# ## ESPN FREE AGENT DATA HAS BEEN GRABBED + CLEANED
# next step with this is to build script to grab multiple years of this data

# %%
def espn_MLB_free_agents(year):
    #URL
    url = (f"http://www.espn.com/mlb/freeagents/_/year/{year}/type/dollars")
    print(f"Checking url: {url}")
    response = requests.get(url)
    page = response.text
    
    #BS for web scraping - table is pure HTML
    soup = BeautifulSoup(page,"html5lib")
    
    #Col Names - just to make sure all tables are the same for safety
    col_name_all = soup.find_all(class_="colhead")[1]
    col_names_list=[]
    for name in col_name_all.find_all("td"):
        col_names_list.append(name.text)
        
    #Players are both in class oddrow and even row
    #Using regex to grab both at once
    rowplayer_regex = re.compile('.*row\splayer.*')
        
    #grab players, using regex
    free_agents_list = soup.find_all(class_=rowplayer_regex)
    
    free_agents_one_year = {} #empty dict to add player and his data to
    for row in free_agents_list: #go through all players on site
        items = row.find_all('td') #find table data elements
        player = items[0].find('a').text #name will be first column, take text from a tag
        free_agents_one_year[player] = [i.text for i in items[1:]] #rest of data for table
    
    #placeholder dataframe, we will add to master after cleansing
    df = pd.DataFrame.from_dict(data=free_agents_one_year,orient='index')
    df.reset_index(inplace=True)
    #reset index because player name shouldn't be index
    #We'll need it to join on our MLB hitting data
    
    #Data Cleaning Time
    #Rename Columns to match ESPN's
    col_names_dict = {"index":"PLAYER",0:"POS",1:"AGE",2:"STATUS",\
                     3:"OLD_TEAM",4:"NEW_TEAM",5:"YRS",6:"RK"\
                      ,7:"DOLLARS"}
    df.rename(columns=col_names_dict,inplace=True)
    #Next Step - Add Free Agent Year as Column
    df["PLAYER_YEAR"]=df["PLAYER"] + f" {year}"
    print(df.head())
    return df #return df, we will append outside function

# %%
import copy
free_agents_backup = copy.copy(free_agents_17df)
free_agents_master = free_agents_backup

# %%
for inp_year in range(2010,2017,1):
    df = pd.DataFrame()
    df = espn_MLB_free_agents(inp_year)
    free_agents_master.append(df)
    print(f"{inp_year} has been added to master")
    print(free_agents_master.head())
    print("**********************************")
# Out:
# Checking url: http://www.espn.com/mlb/freeagents/_/year/2010/type/dollars
#           PLAYER POS AGE      STATUS   OLD_TEAM   NEW_TEAM YRS RK  \
# 0  Carl Crawford  LF  36  Signed (A)       Rays    Red Sox   7  2
# 1   Jayson Werth  LF  38  Signed (A)   Phillies  Nationals   7  3
# 2      Cliff Lee  SP  39  Signed (A)    Rangers   Phillies   5  1
# 3  Adrian Beltre  3B  39  Signed (A)    Red Sox    Rangers   6  4
# 4      Adam Dunn  DH  38  Signed (A)  Nationals  White Sox   4  6
#
#         DOLLARS         PLAYER_YEAR
# 0  $142,000,000  Carl Crawford 2010
# 1  $126,000,000   Jayson Werth 2010
# 2  $120,000,000      Cliff Lee 2010
# 3   $96,000,000  Adrian Beltre 2010
# 4   $56,000,000      Adam Dunn 2010
# 2010 has been added to master
#           PLAYER POS AGE  STATUS      OLD_TEAM  NEW_TEAM YRS RK       DOLLARS  \
# 0    Eric Hosmer  1B  28  Signed        Royals    Padres   8  7  $144,000,000
# 1     Yu Darvish  SP  31  Signed       Dodgers      Cubs   6  1  $126,000,000
# 2  J.D. Martinez  RF  30  Signed  Diamondbacks   Red Sox   5  6  $110,000,000
# 3   Lorenzo Cain  CF  32  Signed        Royals   Brewers   5  2   $80,000,000
# 4   Jake Arrieta  SP  32  Signed          Cubs  Phillies   3  4   $75,000,000
#
#           PLAYER_YEAR
# 0    Eric Hosmer 2017
# 1     Yu Darvish 2017
# 2  J.D. Martinez 2017
# 3   Lorenzo Cain 2017
# 4   Jake Arrieta 2017
# **********************************
# Checking url: http://www.espn.com/mlb/freeagents/_/year/2011/type/dollars
#            PLAYER POS AGE      STATUS   OLD_TEAM NEW_TEAM YRS RK  \
# 0   Albert Pujols  DH  38  Signed (A)  Cardinals   Angels  10  2
# 1  Prince Fielder  DH  33  Signed (A)    Brewers   Tigers   9  1
# 2      Jose Reyes  SS  34  Signed (A)       Mets  Marlins   6  4
# 3     C.J. Wilson  SP  37      Signed    Rangers   Angels   5  8
# 4      Yu Darvish  SP  31      Signed      Japan  Rangers   6  3
#
#         DOLLARS          PLAYER_YEAR
# 0  $250,000,000   Albert Pujols 2011
# 1  $214,000,000  Prince Fielder 2011
# 2  $106,000,000      Jose Reyes 2011
# 3   $77,500,000     C.J. Wilson 2011
# 4   $60,000,000      Yu Darvish 2011
# 2011 has been added to master
#           PLAYER POS AGE  STATUS      OLD_TEAM  NEW_TEAM YRS RK       DOLLARS  \
# 0    Eric Hosmer  1B  28  Signed        Royals    Padres   8  7  $144,000,000
# 1     Yu Darvish  SP  31  Signed       Dodgers      Cubs   6  1  $126,000,000
# 2  J.D. Martinez  RF  30  Signed  Diamondbacks   Red Sox   5  6  $110,000,000
# 3   Lorenzo Cain  CF  32  Signed        Royals   Brewers   5  2   $80,000,000
# 4   Jake Arrieta  SP  32  Signed          Cubs  Phillies   3  4   $75,000,000
#
#           PLAYER_YEAR
# 0    Eric Hosmer 2017
# 1     Yu Darvish 2017
# 2  J.D. Martinez 2017
# 3   Lorenzo Cain 2017
# 4   Jake Arrieta 2017
# **********************************
# Checking url: http://www.espn.com/mlb/freeagents/_/year/2012/type/dollars
#              PLAYER POS AGE  STATUS OLD_TEAM NEW_TEAM YRS  RK       DOLLARS  \
# 0      Zack Greinke  SP  34  Signed   Angels  Dodgers   6   1  $147,000,000
# 1     Josh Hamilton  LF  36  Signed  Rangers   Angels   5   3  $123,000,000
# 2    Anibal Sanchez  SP  34  Agreed   Tigers   Tigers   5   9   $80,000,000
# 3  Melvin Upton Jr.  CF  33  Signed     Rays   Braves   5   2   $75,250,000
# 4      Nick Swisher  LF  37  Signed  Yankees  Indians   4  10   $56,000,000
#
#              PLAYER_YEAR
# 0      Zack Greinke 2012
# 1     Josh Hamilton 2012
# 2    Anibal Sanchez 2012
# 3  Melvin Upton Jr. 2012
# 4      Nick Swisher 2012
# 2012 has been added to master
#           PLAYER POS AGE  STATUS      OLD_TEAM  NEW_TEAM YRS RK       DOLLARS  \
# 0    Eric Hosmer  1B  28  Signed        Royals    Padres   8  7  $144,000,000
# 1     Yu Darvish  SP  31  Signed       Dodgers      Cubs   6  1  $126,000,000
# 2  J.D. Martinez  RF  30  Signed  Diamondbacks   Red Sox   5  6  $110,000,000
# 3   Lorenzo Cain  CF  32  Signed        Royals   Brewers   5  2   $80,000,000
# 4   Jake Arrieta  SP  32  Signed          Cubs  Phillies   3  4   $75,000,000
#
#           PLAYER_YEAR
# 0    Eric Hosmer 2017
# 1     Yu Darvish 2017
# 2  J.D. Martinez 2017
# 3   Lorenzo Cain 2017
# 4   Jake Arrieta 2017
# **********************************
# Checking url: http://www.espn.com/mlb/freeagents/_/year/2013/type/dollars
#             PLAYER POS AGE  STATUS OLD_TEAM  NEW_TEAM YRS  RK       DOLLARS  \
# 0    Robinson Cano  2B  35  Signed  Yankees  Mariners  10   1  $240,000,000
# 1  Masahiro Tanaka  SP  29  Signed    Japan   Yankees   7  NR  $155,000,000
# 2  Jacoby Ellsbury  CF  34  Signed  Red Sox   Yankees   7   2  $153,000,000
# 3    Shin-Soo Choo  RF  35  Signed     Reds   Rangers   7   5  $130,000,000
# 4     Brian McCann   C  34  Signed   Braves   Yankees   5   8   $85,000,000
#
#             PLAYER_YEAR
# 0    Robinson Cano 2013
# 1  Masahiro Tanaka 2013
# 2  Jacoby Ellsbury 2013
# 3    Shin-Soo Choo 2013
# 4     Brian McCann 2013
# 2013 has been added to master
#           PLAYER POS AGE  STATUS      OLD_TEAM  NEW_TEAM YRS RK       DOLLARS  \
# 0    Eric Hosmer  1B  28  Signed        Royals    Padres   8  7  $144,000,000
# 1     Yu Darvish  SP  31  Signed       Dodgers      Cubs   6  1  $126,000,000
# 2  J.D. Martinez  RF  30  Signed  Diamondbacks   Red Sox   5  6  $110,000,000
# 3   Lorenzo Cain  CF  32  Signed        Royals   Brewers   5  2   $80,000,000
# 4   Jake Arrieta  SP  32  Signed          Cubs  Phillies   3  4   $75,000,000
#
#           PLAYER_YEAR
# 0    Eric Hosmer 2017
# 1     Yu Darvish 2017
# 2  J.D. Martinez 2017
# 3   Lorenzo Cain 2017
# 4   Jake Arrieta 2017
# **********************************
# Checking url: http://www.espn.com/mlb/freeagents/_/year/2014/type/dollars
#            PLAYER POS AGE  STATUS   OLD_TEAM   NEW_TEAM YRS RK       DOLLARS  \
# 0    Max Scherzer  SP  33  Signed     Tigers  Nationals   7  1  $210,000,000
# 1      Jon Lester  SP  34  Signed  Athletics       Cubs   6  2  $155,000,000
# 2  Pablo Sandoval  3B  31  Signed     Giants    Red Sox   5  6   $95,000,000
# 3  Hanley Ramirez  DH  34  Signed    Dodgers    Red Sox   4  3   $88,000,000
# 4  Russell Martin   C  35  Signed    Pirates  Blue Jays   5  8   $82,000,000
#
#            PLAYER_YEAR
# 0    Max Scherzer 2014
# 1      Jon Lester 2014
# 2  Pablo Sandoval 2014
# 3  Hanley Ramirez 2014
# 4  Russell Martin 2014
# 2014 has been added to master
#           PLAYER POS AGE  STATUS      OLD_TEAM  NEW_TEAM YRS RK       DOLLARS  \
# 0    Eric Hosmer  1B  28  Signed        Royals    Padres   8  7  $144,000,000
# 1     Yu Darvish  SP  31  Signed       Dodgers      Cubs   6  1  $126,000,000
# 2  J.D. Martinez  RF  30  Signed  Diamondbacks   Red Sox   5  6  $110,000,000
# 3   Lorenzo Cain  CF  32  Signed        Royals   Brewers   5  2   $80,000,000
# 4   Jake Arrieta  SP  32  Signed          Cubs  Phillies   3  4   $75,000,000
#
#           PLAYER_YEAR
# 0    Eric Hosmer 2017
# 1     Yu Darvish 2017
# 2  J.D. Martinez 2017
# 3   Lorenzo Cain 2017
# 4   Jake Arrieta 2017
# **********************************
# Checking url: http://www.espn.com/mlb/freeagents/_/year/2015/type/dollars
#           PLAYER POS AGE  STATUS   OLD_TEAM      NEW_TEAM YRS RK  \
# 0    David Price  SP  32  Signed  Blue Jays       Red Sox   7  3
# 1   Zack Greinke  SP  34  Signed    Dodgers  Diamondbacks   6  2
# 2  Jason Heyward  RF  28  Signed  Cardinals          Cubs   8  1
# 3    Chris Davis  1B  32  Signed    Orioles       Orioles   7  7
# 4   Justin Upton  LF  30  Signed     Padres        Tigers   6  4
#
#         DOLLARS         PLAYER_YEAR
# 0  $217,000,000    David Price 2015
# 1  $206,500,000   Zack Greinke 2015
# 2  $184,000,000  Jason Heyward 2015
# 3  $161,000,000    Chris Davis 2015
# 4  $132,750,000   Justin Upton 2015
# 2015 has been added to master
#           PLAYER POS AGE  STATUS      OLD_TEAM  NEW_TEAM YRS RK       DOLLARS  \
# 0    Eric Hosmer  1B  28  Signed        Royals    Padres   8  7  $144,000,000
# 1     Yu Darvish  SP  31  Signed       Dodgers      Cubs   6  1  $126,000,000
# 2  J.D. Martinez  RF  30  Signed  Diamondbacks   Red Sox   5  6  $110,000,000
# 3   Lorenzo Cain  CF  32  Signed        Royals   Brewers   5  2   $80,000,000
# 4   Jake Arrieta  SP  32  Signed          Cubs  Phillies   3  4   $75,000,000
#
#           PLAYER_YEAR
# 0    Eric Hosmer 2017
# 1     Yu Darvish 2017
# 2  J.D. Martinez 2017
# 3   Lorenzo Cain 2017
# 4   Jake Arrieta 2017
# **********************************
# Checking url: http://www.espn.com/mlb/freeagents/_/year/2016/type/dollars
#             PLAYER POS AGE  STATUS OLD_TEAM   NEW_TEAM YRS  RK       DOLLARS  \
# 0  Yoenis Cespedes  LF  32  Signed     Mets       Mets   4   1  $110,000,000
# 1  Aroldis Chapman  RP  30  Signed     Cubs    Yankees   5  11   $86,000,000
# 2    Dexter Fowler  RF  32  Signed     Cubs  Cardinals   5   2   $82,500,000
# 3    Kenley Jansen  RP  30  Signed  Dodgers    Dodgers   5   8   $80,000,000
# 4      Ian Desmond  LF  32  Signed  Rangers    Rockies   5  10   $70,000,000
#
#             PLAYER_YEAR
# 0  Yoenis Cespedes 2016
# 1  Aroldis Chapman 2016
# 2    Dexter Fowler 2016
# 3    Kenley Jansen 2016
# 4      Ian Desmond 2016
# 2016 has been added to master
#           PLAYER POS AGE  STATUS      OLD_TEAM  NEW_TEAM YRS RK       DOLLARS  \
# 0    Eric Hosmer  1B  28  Signed        Royals    Padres   8  7  $144,000,000
# 1     Yu Darvish  SP  31  Signed       Dodgers      Cubs   6  1  $126,000,000
# 2  J.D. Martinez  RF  30  Signed  Diamondbacks   Red Sox   5  6  $110,000,000
# 3   Lorenzo Cain  CF  32  Signed        Royals   Brewers   5  2   $80,000,000
# 4   Jake Arrieta  SP  32  Signed          Cubs  Phillies   3  4   $75,000,000
#
#           PLAYER_YEAR
# 0    Eric Hosmer 2017
# 1     Yu Darvish 2017
# 2  J.D. Martinez 2017
# 3   Lorenzo Cain 2017
# 4   Jake Arrieta 2017
# **********************************

# %%
free_agents_master.sample(15)
# Out:
#               PLAYER POS AGE  STATUS      OLD_TEAM      NEW_TEAM YRS  RK  \
# 30    Luke Gregerson  RP  33  Signed        Astros     Cardinals   2  NR
# 163   Fernando Salas  RP  32  Signed        Angels  Diamondbacks      NR
# 27      Steve Cishek  RP  31  Signed          Rays          Cubs   2  NR
# 110     Chris Carter  1B  31  Signed     Athletics        Angels      NR
# 22      Jason Vargas  RP  35  Signed        Royals          Mets   2  35
# 114    Kyle Crockett  RP  26  Signed          Reds          Reds      NR
# 157     Colby Rasmus  LF  31  Signed          Rays       Orioles      NR
# 107     Blaine Boyer  RP  36  Signed       Red Sox        Royals      NR
# 8          Jay Bruce  RF  31  Signed       Indians          Mets   3  12
# 53   Miguel Gonzalez  SP  33  Signed       Rangers     White Sox   1  NR
# 61     Eduardo Nunez  2B  30  Signed       Red Sox       Red Sox   1  33
# 127      J.J. Hoover  RP  30  Signed  Diamondbacks       Brewers      NR
# 123     A.J. Griffin  SP  30  Signed       Rangers          Mets      NR
# 128   Jae-Gyun Hwang  3B  30  Signed        Giants            --      NR
# 43    Brian Duensing  RP  35  Signed          Cubs          Cubs   2  NR
#
#          DOLLARS           PLAYER_YEAR
# 30   $11,000,000   Luke Gregerson 2017
# 163     Minor Lg   Fernando Salas 2017
# 27   $13,000,000     Steve Cishek 2017
# 110     Minor Lg     Chris Carter 2017
# 22   $16,000,000     Jason Vargas 2017
# 114     Minor Lg    Kyle Crockett 2017
# 157     Minor Lg     Colby Rasmus 2017
# 107     Minor Lg     Blaine Boyer 2017
# 8    $39,000,000        Jay Bruce 2017
# 53    $4,750,000  Miguel Gonzalez 2017
# 61    $4,000,000    Eduardo Nunez 2017
# 127     Minor Lg      J.J. Hoover 2017
# 123     Minor Lg     A.J. Griffin 2017
# 128           --   Jae-Gyun Hwang 2017
# 43    $7,000,000   Brian Duensing 2017
