# %% [markdown]
# This notebook combines the fangraphs advanced, value, and standard pages, and then merges this (inner join) on
# the ESPN free agent data. We then go through many of the columns and massage/clean our data

# %%
import pickle
import pandas as pd
import numpy as np
import copy
import seaborn as sns

# %%
#Import our 4 web scrpe files
#these 3 are from fangraphs
advanced_df = pickle.load( open( "df_advanced.pkl", "rb" ) )
standard_df = pickle.load( open( "df_standard.pkl", "rb" ) )
value_df = pickle.load( open( "df_value.pkl", "rb" ) )
#free_agents_df is ESPN
free_agents_df = pickle.load( open( "free_agents_master.pkl", "rb" ) )

# %%
advanced_df.head()
advanced_df.count()
# Out:
# PA       3567
# BB%      3567
# K%       3567
# BB/K     3567
# AVG      3567
# OBP      3567
# SLG      3567
# OPS      3567
# ISO      3567
# Spd      3567
# BABIP    3567
# UBR      3567
# wGDP     3567
# wSB      3567
# wRC      3567
# wRAA     3567
# wOBA     3567
# wRC+     3567
# dtype: int64

# %%
standard_df.head()
standard_df.count()
# Out:
# G      3567
# AB     3567
# PA     3567
# H      3567
# 1B     3567
# 2B     3567
# 3B     3567
# HR     3567
# R      3567
# RBI    3567
# BB     3567
# IBB    3567
# SO     3567
# HBP    3567
# SF     3567
# SH     3567
# GDP    3567
# SB     3567
# CS     3567
# AVG    3567
# dtype: int64

# %%
value_df.count()
# Out:
# Batting         3567
# Base Running    3567
# Fielding        3567
# Positional      3567
# Offense         3567
# Defense         3567
# League          3567
# Replacement     3567
# RAR             3567
# WAR             3567
# Dollars         3567
# dtype: int64

# %%
#Joining on the index for both columns
#master_df becomes our primary dataframe
master_df = pd.merge(advanced_df, standard_df, how='inner',left_index=True,right_index=True)
master_df = pd.merge(master_df,value_df,how='inner',left_index=True,right_index=True)

# %%
#master_df is now a combo of advanced, standard and value
master_df.count().head() #3567 - our merge worked
# Out:
# PA_x     3567
# BB%      3567
# K%       3567
# BB/K     3567
# AVG_x    3567
# dtype: int64

# %%
#Save progress
with open('df_standard_value_advanced.pkl', 'wb') as picklefile:
    pickle.dump(master_df, picklefile)

# %%
#Now, let's join on the Free Agent Data we have - should be around 600 names left?

# %%
free_agents_df.groupby('PLAYER_YEAR').count().sort_values(by="PLAYER",ascending=True)
# Out:
#                           PLAYER  POS  AGE  STATUS  OLD_TEAM  NEW_TEAM  YRS  \
# PLAYER_YEAR
# A.J. Achter 2016               1    1    1       1         1         1    1
# Mark Reynolds 2013             1    1    1       1         1         1    1
# Mark Reynolds 2012             1    1    1       1         1         1    1
# Mark Melancon 2016             1    1    1       1         1         1    1
# Mark Lowe 2015                 1    1    1       1         1         1    1
# Mark Kotsay 2013               1    1    1       1         1         1    1
# Mark Kotsay 2011               1    1    1       1         1         1    1
# Mark Kotsay 2010               1    1    1       1         1         1    1
# Mark Hendrickson 2010          1    1    1       1         1         1    1
# Mark Ellis 2014                1    1    1       1         1         1    1
# Mark Ellis 2013                1    1    1       1         1         1    1
# Mark Ellis 2011                1    1    1       1         1         1    1
# Mark DeRosa 2013               1    1    1       1         1         1    1
# Mark DeRosa 2011               1    1    1       1         1         1    1
# Mark Buehrle 2011              1    1    1       1         1         1    1
# Mariano Rivera 2013            1    1    1       1         1         1    1
# Mark Reynolds 2014             1    1    1       1         1         1    1
# Mark Reynolds 2015             1    1    1       1         1         1    1
# Mark Reynolds 2016             1    1    1       1         1         1    1
# Mark Trumbo 2016               1    1    1       1         1         1    1
# Matt Belisle 2017              1    1    1       1         1         1    1
# Matt Belisle 2016              1    1    1       1         1         1    1
# Matt Belisle 2015              1    1    1       1         1         1    1
# Matt Belisle 2014              1    1    1       1         1         1    1
# Matt Albers 2017               1    1    1       1         1         1    1
# Matt Albers 2016               1    1    1       1         1         1    1
# Matt Albers 2015               1    1    1       1         1         1    1
# Mariano Rivera 2012            1    1    1       1         1         1    1
# Matt Albers 2013               1    1    1       1         1         1    1
# Matt Adams 2017                1    1    1       1         1         1    1
# ...                          ...  ...  ...     ...       ...       ...  ...
# Eugenio Velez 2010             1    1    1       1         1         1    1
# Erik Kratz 2017                1    1    1       1         1         1    1
# Erik Johnson 2016              1    1    1       1         1         1    1
# Erik Bedard 2013               1    1    1       1         1         1    1
# Erik Bedard 2011               1    1    1       1         1         1    1
# Erik Bedard 2010               1    1    1       1         1         1    1
# Erick Aybar 2017               1    1    1       1         1         1    1
# Erick Aybar 2016               1    1    1       1         1         1    1
# Ervin Santana 2014             1    1    1       1         1         1    1
# Eric Thames 2016               1    1    1       1         1         1    1
# Fernando Rodney 2017           1    1    1       1         1         1    1
# Fernando Salas 2017            1    1    1       1         1         1    1
# Freddy Garcia 2011             1    1    1       1         1         1    1
# Freddy Garcia 2010             1    1    1       1         1         1    1
# Fred Lewis 2010                1    1    1       1         1         1    1
# Franklin Morales 2015          1    1    1       1         1         1    1
# Franklin Morales 2014          1    1    1       1         1         1    1
# Franklin Gutierrez 2016        1    1    1       1         1         1    1
# Franklin Gutierrez 2015        1    1    1       1         1         1    1
# Fernando Salas 2016            1    1    1       1         1         1    1
# Franklin Gutierrez 2013        1    1    1       1         1         1    1
# Frank Francisco 2010           1    1    1       1         1         1    1
# Francisco Rodriguez 2014       1    1    1       1         1         1    1
# Francisco Rodriguez 2013       1    1    1       1         1         1    1
# Francisco Liriano 2017         1    1    1       1         1         1    1
# Francisco Liriano 2014         1    1    1       1         1         1    1
# Francisco Liriano 2012         1    1    1       1         1         1    1
# Francisco Cordero 2011         1    1    1       1         1         1    1
# Frank Francisco 2011           1    1    1       1         1         1    1
# Zack Greinke 2015              1    1    1       1         1         1    1
#
#                           RK  DOLLARS
# PLAYER_YEAR
# A.J. Achter 2016           1        1
# Mark Reynolds 2013         1        1
# Mark Reynolds 2012         1        1
# Mark Melancon 2016         1        1
# Mark Lowe 2015             1        1
# Mark Kotsay 2013           1        1
# Mark Kotsay 2011           1        1
# Mark Kotsay 2010           1        1
# Mark Hendrickson 2010      1        1
# Mark Ellis 2014            1        1
# Mark Ellis 2013            1        1
# Mark Ellis 2011            1        1
# Mark DeRosa 2013           1        1
# Mark DeRosa 2011           1        1
# Mark Buehrle 2011          1        1
# Mariano Rivera 2013        1        1
# Mark Reynolds 2014         1        1
# Mark Reynolds 2015         1        1
# Mark Reynolds 2016         1        1
# Mark Trumbo 2016           1        1
# Matt Belisle 2017          1        1
# Matt Belisle 2016          1        1
# Matt Belisle 2015          1        1
# Matt Belisle 2014          1        1
# Matt Albers 2017           1        1
# Matt Albers 2016           1        1
# Matt Albers 2015           1        1
# Mariano Rivera 2012        1        1
# Matt Albers 2013           1        1
# Matt Adams 2017            1        1
# ...                       ..      ...
# Eugenio Velez 2010         1        1
# Erik Kratz 2017            1        1
# Erik Johnson 2016          1        1
# Erik Bedard 2013           1        1
# Erik Bedard 2011           1        1
# Erik Bedard 2010           1        1
# Erick Aybar 2017           1        1
# Erick Aybar 2016           1        1
# Ervin Santana 2014         1        1
# Eric Thames 2016           1        1
# Fernando Rodney 2017       1        1
# Fernando Salas 2017        1        1
# Freddy Garcia 2011         1        1
# Freddy Garcia 2010         1        1
# Fred Lewis 2010            1        1
# Franklin Morales 2015      1        1
# Franklin Morales 2014      1        1
# Franklin Gutierrez 2016    1        1
# Franklin Gutierrez 2015    1        1
# Fernando Salas 2016        1        1
# Franklin Gutierrez 2013    1        1
# Frank Francisco 2010       1        1
# Francisco Rodriguez 2014   1        1
# Francisco Rodriguez 2013   1        1
# Francisco Liriano 2017     1        1
# Francisco Liriano 2014     1        1
# Francisco Liriano 2012     1        1
# Francisco Cordero 2011     1        1
# Frank Francisco 2011       1        1
# Zack Greinke 2015          1        1
#
# [1257 rows x 9 columns]

# %%
free_agents_df = free_agents_df.drop_duplicates() #some dupes - easy enough to drop
free_agents_df.groupby('PLAYER_YEAR').count().head() #all 1's
# Out:
#                    PLAYER  POS  AGE  STATUS  OLD_TEAM  NEW_TEAM  YRS  RK  \
# PLAYER_YEAR
# A.J. Achter 2016        1    1    1       1         1         1    1   1
# A.J. Burnett 2013       1    1    1       1         1         1    1   1
# A.J. Burnett 2014       1    1    1       1         1         1    1   1
# A.J. Burnett 2015       1    1    1       1         1         1    1   1
# A.J. Ellis 2016         1    1    1       1         1         1    1   1
#
#                    DOLLARS
# PLAYER_YEAR
# A.J. Achter 2016         1
# A.J. Burnett 2013        1
# A.J. Burnett 2014        1
# A.J. Burnett 2015        1
# A.J. Ellis 2016          1

# %%
#merge master with free_agents_df - our ESPN data
master_df = pd.merge(master_df,free_agents_df,how='inner',\
                     left_index=True,right_on="PLAYER_YEAR")

# %%
#PLAYER_YEAR can be our index - easy to see what the row represents
master_df.set_index(["PLAYER_YEAR"],drop=False,inplace=True)

# %%
master_df.head()
# Out:
#                         PA_x     BB%      K%  BB/K AVG_x   OBP   SLG    OPS  \
# PLAYER_YEAR
# Jim Thome 2010           340  17.6 %  24.1 %  0.73  .283  .412  .627  1.039
# J.D. Martinez 2017       489  10.8 %  26.2 %  0.41  .303  .376  .690  1.066
# Victor Martinez 2014     641  10.9 %   6.6 %  1.67  .335  .409  .565   .974
# Franklin Gutierrez 2015  189   7.4 %  28.6 %  0.26  .292  .354  .620   .974
# Paul Konerko 2010        631  11.4 %  17.4 %  0.65  .312  .393  .584   .977
#
#                           ISO  Spd           ...             \
# PLAYER_YEAR                                  ...
# Jim Thome 2010           .344  2.3           ...
# J.D. Martinez 2017       .387  4.7           ...
# Victor Martinez 2014     .230  2.0           ...
# Franklin Gutierrez 2015  .327  1.0           ...
# Paul Konerko 2010        .272  1.7           ...
#
#                                      PLAYER POS AGE      STATUS      OLD_TEAM  \
# PLAYER_YEAR
# Jim Thome 2010                    Jim Thome  DH  47      Signed         Twins
# J.D. Martinez 2017            J.D. Martinez  RF  30      Signed  Diamondbacks
# Victor Martinez 2014        Victor Martinez  DH  39      Signed        Tigers
# Franklin Gutierrez 2015  Franklin Gutierrez  LF  35      Signed      Mariners
# Paul Konerko 2010              Paul Konerko  DH  42  Signed (A)     White Sox
#
#                           NEW_TEAM YRS  RK       DOLLARS  \
# PLAYER_YEAR
# Jim Thome 2010               Twins   1  24    $3,000,000
# J.D. Martinez 2017         Red Sox   5   6  $110,000,000
# Victor Martinez 2014        Tigers   4  12   $68,000,000
# Franklin Gutierrez 2015   Mariners   1  NR            --
# Paul Konerko 2010        White Sox   3  12   $37,500,000
#
#                                      PLAYER_YEAR
# PLAYER_YEAR
# Jim Thome 2010                    Jim Thome 2010
# J.D. Martinez 2017            J.D. Martinez 2017
# Victor Martinez 2014        Victor Martinez 2014
# Franklin Gutierrez 2015  Franklin Gutierrez 2015
# Paul Konerko 2010              Paul Konerko 2010
#
# [5 rows x 59 columns]

# %% [markdown]
# ## Data Cleaning Time

# %%
#BB%, K% have percentage signs
master_df[["BB%","K%"]].head()
# Out:
#                             BB%      K%
# PLAYER_YEAR
# Jim Thome 2010           17.6 %  24.1 %
# J.D. Martinez 2017       10.8 %  26.2 %
# Victor Martinez 2014     10.9 %   6.6 %
# Franklin Gutierrez 2015   7.4 %  28.6 %
# Paul Konerko 2010        11.4 %  17.4 %

# %%
#Replace % with empty
for col in ["BB%","K%"]:
    master_df[col] = master_df[col].str.replace(" \%","")

# %%
#Replace $ or Commas in DOLLARS with blank
master_df["DOLLARS"] = master_df["DOLLARS"].str.replace("\$|,","")
#Replace $ or Commas in Dollars with blank
master_df["Dollars"] = master_df["Dollars"].str.replace("\$|,","")

# %%
# 362 of the 500+ names have reported MLB salaries.
master_df[master_df["DOLLARS"].str.isnumeric()] 
master_df[master_df["Dollars"].str.isnumeric()]

# %%
#I will set the Minor League salary to the league minimum

# %%
#135 guys signed to minor league deals - we'll give them the League Minimum salary
minimum_players = list(master_df[master_df.DOLLARS=="Minor Lg"]["PLAYER_YEAR"]) 
# len(minimum_players)

# %% [markdown]
# https://www.statista.com/statistics/256187/minimum-salary-of-players-in-major-league-baseball/
# Average Minimum Salary of MLB players from 2011-2018 is around $497000 - we'll use that as our value for these guys

# %%
#Some of these guys have YRS missing as well - we're assuming they signed 1 year, league minimum contracts
master_df["YRS"] = master_df["YRS"].apply(pd.to_numeric,errors='ignore')
yrs_missing = list(master_df[master_df["YRS"].isnull()].index)

# %%
yrs_missing
# Out:
# ['Ryan Raburn 2015',
#  'Jim Edmonds 2010',
#  'Colby Rasmus 2017',
#  'Adam Lind 2017',
#  'Chipper Jones 2012',
#  'Daniel Nava 2017',
#  'Mark Reynolds 2016',
#  'Jason Giambi 2010',
#  'Pat Burrell 2011',
#  'Gregg Zaun 2010',
#  'Josh Willingham 2014',
#  'Matt Stairs 2010',
#  'Jon Jay 2017',
#  'David Ross 2016',
#  'Mark DeRosa 2013',
#  'Todd Helton 2013',
#  'Michael Young 2013',
#  'David Murphy 2015',
#  'Marlon Byrd 2015',
#  'Corey Patterson 2010',
#  'Lastings Milledge 2010',
#  'Chris Carter 2010',
#  'Lance Berkman 2013',
#  'Jorge Posada 2011',
#  'Brooks Conrad 2011',
#  'Aaron Hill 2016',
#  'Danny Valencia 2017',
#  'Bobby Abreu 2014',
#  'Justin Turner 2013',
#  'Ryan Raburn 2016',
#  'Jeff Francoeur 2015',
#  'Gregor Blanco 2017',
#  'Ramon Santiago 2014',
#  'Delwyn Young 2010',
#  'Endy Chavez 2014',
#  'Willie Harris 2011',
#  'Ryan Ludwick 2014',
#  'Patrick Kivlehan 2017',
#  'Lyle Overbay 2013',
#  'Mike Napoli 2017',
#  'Chris Denorfia 2015',
#  'James Loney 2016',
#  'Michael Bourn 2016',
#  'Adam Kennedy 2010',
#  'Carlos Pena 2013',
#  'Chris Coghlan 2013',
#  'Russell Branyan 2011',
#  'Juan Pierre 2011',
#  'Kelly Johnson 2014',
#  'Felipe Lopez 2010',
#  'Will Venable 2015',
#  'Randy Winn 2010',
#  'A.J. Ellis 2017',
#  'Willie Harris 2010',
#  'Conor Jackson 2011',
#  'Eric Fryer 2016',
#  'Rick Ankiel 2011',
#  'Austin Jackson 2016',
#  'Orlando Cabrera 2010',
#  'Peter Bourjos 2016',
#  'Munenori Kawasaki 2013',
#  'Reed Johnson 2010',
#  'Ronny Paulino 2011',
#  'Drew Stubbs 2015',
#  'Miguel Montero 2017',
#  'Ryan Hanigan 2017',
#  'Scott Hairston 2010',
#  'Kevin Kouzmanoff 2011',
#  'Ichiro Suzuki 2017',
#  'Munenori Kawasaki 2014',
#  'Brad Hawpe 2011',
#  'Ben Revere 2017',
#  'Chris Carter 2017',
#  'Gregorio Petit 2016',
#  'Jimmy Rollins 2015',
#  'Skip Schumaker 2015',
#  'Josh Bard 2010',
#  'Jace Peterson 2017',
#  'Gordon Beckham 2016',
#  'Rajai Davis 2017',
#  'Cliff Pennington 2017',
#  'Aaron Miles 2010',
#  'Cody Asche 2016',
#  'Derek Jeter 2014',
#  'Ryan Goins 2017',
#  'Jarrod Saltalamacchia 2016',
#  'Bryan Holaday 2016',
#  'Corey Patterson 2011',
#  'Alejandro De Aza 2016',
#  'Kevin Frandsen 2010',
#  'Carlos Guillen 2011',
#  'Clint Barmes 2015',
#  'Ronny Cedeno 2013',
#  'Ramon Cabrera 2016',
#  'Reed Johnson 2014',
#  'Gregor Blanco 2016',
#  'Nick Punto 2014',
#  'Erick Aybar 2016',
#  'Wil Nieves 2014',
#  'Casey Kotchman 2010',
#  'Shane Victorino 2015',
#  'Eric Chavez 2010',
#  'Jose Lopez 2011',
#  'Chris Coghlan 2016',
#  'Hyun Soo Kim 2017',
#  'Ramon Santiago 2013',
#  'Matt Diaz 2012',
#  'Alexi Amarista 2017',
#  'Gabe Kapler 2010',
#  'Ryan Spilborghs 2011',
#  'Omar Vizquel 2011',
#  'Omar Quintanilla 2013',
#  'Darwin Barney 2017',
#  'Adam Rosales 2017',
#  'Alen Hanson 2017',
#  'Yorvit Torrealba 2013',
#  'Trevor Plouffe 2017',
#  'Alex Cora 2011',
#  'Yuniesky Betancourt 2013',
#  'Orlando Cabrera 2011',
#  'Matt Joyce 2015',
#  'Paul Konerko 2014',
#  'Bill Hall 2011',
#  'Danny Santana 2017',
#  'Chad Tracy 2013',
#  'Alexi Casilla 2013',
#  'Sam Fuld 2013',
#  'Jason Michaels 2011',
#  'Nate Schierholtz 2014',
#  'Casey McGehee 2015',
#  'Andres Blanco 2017',
#  'Gerald Laird 2014',
#  'Koyie Hill 2011',
#  'Omar Vizquel 2012',
#  'Craig Counsell 2011',
#  'Jamey Carroll 2013',
#  'Pedro Feliz 2010',
#  'Jose Lobaton 2017',
#  'Mark Kotsay 2013',
#  'Henry Blanco 2013',
#  'Miguel Cairo 2012',
#  'Mark Ellis 2014',
#  'Ryan Hanigan 2016',
#  'Chris Stewart 2017',
#  'Arismendy Alcantara 2017']

# %%
'''
For these players - set dollars to 497K, YRS to 1
'''
for name in minimum_players:
    master_df.loc[master_df.PLAYER_YEAR==name,"DOLLARS"] = 497000

for name in yrs_missing:
    master_df.loc[master_df.PLAYER_YEAR==name,"YRS"] = int(1)

# %%
master_df["YRS"]
# Out:
# PLAYER_YEAR
# Jim Thome 2010               1.0
# J.D. Martinez 2017           5.0
# Victor Martinez 2014         4.0
# Franklin Gutierrez 2015      1.0
# Paul Konerko 2010            3.0
# Michael Cuddyer 2014         2.0
# Prince Fielder 2011          9.0
# Ryan Raburn 2015             1.0
# Jayson Werth 2010            7.0
# Shin-Soo Choo 2013           7.0
# Zack Cozart 2017             3.0
# Adrian Beltre 2010           6.0
# Carlos Beltran 2011          2.0
# Chris Davis 2015             7.0
# Melky Cabrera 2012           2.0
# Aubrey Huff 2010             2.0
# Albert Pujols 2011          10.0
# Josh Hamilton 2012           5.0
# Robinson Cano 2013          10.0
# Manny Ramirez 2010           1.0
# Adam Dunn 2010               4.0
# Jose Reyes 2011              6.0
# Jonny Gomes 2012             2.0
# Eric Hosmer 2017             8.0
# Jack Cust 2010               1.0
# Edwin Encarnacion 2016       3.0
# Magglio Ordonez 2010         1.0
# Matt Joyce 2016              2.0
# Aramis Ramirez 2011          3.0
# Dioner Navarro 2013          2.0
#                             ...
# Dioner Navarro 2010          1.0
# Sam Fuld 2013                1.0
# Jason Michaels 2011          1.0
# Nate Schierholtz 2014        1.0
# Clint Barmes 2013            1.0
# David Adams 2013             1.0
# Casey McGehee 2015           1.0
# Andres Blanco 2017           1.0
# Wil Nieves 2010              1.0
# Gerald Laird 2014            1.0
# Koyie Hill 2011              1.0
# Omar Vizquel 2012            1.0
# Jason Bay 2012               1.0
# Brendan Ryan 2013            2.0
# Stephen Drew 2014            1.0
# Craig Counsell 2011          1.0
# Jamey Carroll 2013           1.0
# Pedro Feliz 2010             1.0
# Brian Schneider 2011         1.0
# Cesar Izturis 2013           1.0
# Jose Lobaton 2017            1.0
# Leonys Martin 2017           1.0
# Mark Kotsay 2013             1.0
# Henry Blanco 2013            1.0
# Jeff Mathis 2015             1.0
# Miguel Cairo 2012            1.0
# Mark Ellis 2014              1.0
# Ryan Hanigan 2016            1.0
# Chris Stewart 2017           1.0
# Arismendy Alcantara 2017     1.0
# Name: YRS, Length: 534, dtype: float64

# %%
#Players Signed to Major League deals without salaries/yrs reported
#These were grabbed from Baseball Reference
#Players were given NaN if I couldnt find their contract value
fill_in_salaries = {'Alexi Amarista 2016':1100000,
 'Arismendy Alcantara 2017':np.NaN,
 'Clint Barmes 2013':2000000,
 'David Adams 2013':np.NaN,
 'Franklin Gutierrez 2015':1500000,
 'Gerald Laird 2012':3000000,
 'Hyun Soo Kim 2017':np.NaN,
 'Jarrod Saltalamacchia 2015':507500,
 'Jason Bay 2012':1000000,
 'Luke Scott 2013':np.NaN,
 'Lyle Overbay 2011':1000000,
 'Ronny Cedeno 2012':1150000,
 'Ronny Cedeno 2011':1200000,
 'Yuniesky Betancourt 2013':np.NaN,
 'Jon Jay 2017':3000000,
 'Orlando Cabrera 2010':1000000,
 'Ryan Ludwick 2011':2000000,
 'Scott Hairston 2012':2500000,
 'Travis Hafner 2012':2000000}

# %%
#Use fill_in_salaries to update those players
for name,amount in fill_in_salaries.items():
#     print(f"Name: {name}")
    master_df.loc[master_df.PLAYER_YEAR==name,"DOLLARS"] = amount
#     print(master_df.loc[name]["DOLLARS"])

# %%
# This should be empty now - any signed players now have data (or an NaN, if we couldnt find anything)
master_df[(master_df["DOLLARS"]=="--")&(master_df["STATUS"]=="Signed")].sort_values(by="PLAYER")
# Out:
# Empty DataFrame
# Columns: [PA_x, BB%, K%, BB/K, AVG_x, OBP, SLG, OPS, ISO, Spd, BABIP, UBR, wGDP, wSB, wRC, wRAA, wOBA, wRC+, G, AB, PA_y, H, 1B, 2B, 3B, HR, R, RBI, BB, IBB, SO, HBP, SF, SH, GDP, SB, CS, AVG_y, Batting, Base Running, Fielding, Positional, Offense, Defense, League, Replacement, RAR, WAR, Dollars, PLAYER, POS, AGE, STATUS, OLD_TEAM, NEW_TEAM, YRS, RK, DOLLARS, PLAYER_YEAR]
# Index: []
#
# [0 rows x 59 columns]

# %%
#Last - we want to drop retired players
retired_players = master_df[(master_df["DOLLARS"]=="--")].sort_values(by="PLAYER") 
retired_players.head(10)
# Out:
#                      PA_x   BB%    K%  BB/K AVG_x   OBP   SLG   OPS   ISO  \
# PLAYER_YEAR
# Bobby Abreu 2014      155  12.9  13.5  0.95  .248  .342  .338  .680  .090
# Chipper Jones 2012    448  12.7  11.4  1.12  .287  .377  .455  .832  .168
# Craig Counsell 2011   187  10.7  11.2  0.95  .178  .280  .223  .503  .045
# David Ross 2016       205  14.6  26.3  0.56  .229  .338  .446  .784  .217
# Derek Jeter 2014      634   5.5  13.7  0.40  .256  .304  .313  .617  .057
# Jorge Posada 2011     387  10.1  19.6  0.51  .235  .315  .398  .714  .163
# Josh Willingham 2014  364  14.6  28.0  0.52  .215  .346  .397  .743  .182
# Lance Berkman 2013    294  12.9  17.7  0.73  .242  .340  .359  .700  .117
# Mark DeRosa 2013      236  11.9  20.8  0.57  .235  .326  .407  .733  .172
# Mark Ellis 2014       202   6.9  18.8  0.37  .180  .253  .213  .466  .034
#
#                       Spd          ...                    PLAYER POS AGE  \
# PLAYER_YEAR                        ...
# Bobby Abreu 2014      2.4          ...               Bobby Abreu  RF  44
# Chipper Jones 2012    2.1          ...             Chipper Jones  3B  45
# Craig Counsell 2011   4.5          ...            Craig Counsell  2B  47
# David Ross 2016       1.4          ...                David Ross   C  41
# Derek Jeter 2014      3.5          ...               Derek Jeter  SS  43
# Jorge Posada 2011     1.1          ...              Jorge Posada  DH  46
# Josh Willingham 2014  3.8          ...           Josh Willingham  LF  39
# Lance Berkman 2013    1.7          ...             Lance Berkman  DH  42
# Mark DeRosa 2013      2.0          ...               Mark DeRosa  2B  43
# Mark Ellis 2014       4.1          ...                Mark Ellis  2B  40
#
#                        STATUS   OLD_TEAM NEW_TEAM  YRS  RK DOLLARS  \
# PLAYER_YEAR
# Bobby Abreu 2014      Retired       Mets       --  1.0  NR      --
# Chipper Jones 2012    Retired     Braves       --  1.0  NR      --
# Craig Counsell 2011   Retired    Brewers       --  1.0  NR      --
# David Ross 2016       Retired       Cubs       --  1.0  NR      --
# Derek Jeter 2014      Retired    Yankees       --  1.0  NR      --
# Jorge Posada 2011     Retired    Yankees       --  1.0  NR      --
# Josh Willingham 2014  Retired     Royals       --  1.0  NR      --
# Lance Berkman 2013    Retired    Rangers       --  1.0  NR      --
# Mark DeRosa 2013      Retired  Blue Jays       --  1.0  NR      --
# Mark Ellis 2014       Retired  Cardinals       --  1.0  NR      --
#
#                                PLAYER_YEAR
# PLAYER_YEAR
# Bobby Abreu 2014          Bobby Abreu 2014
# Chipper Jones 2012      Chipper Jones 2012
# Craig Counsell 2011    Craig Counsell 2011
# David Ross 2016            David Ross 2016
# Derek Jeter 2014          Derek Jeter 2014
# Jorge Posada 2011        Jorge Posada 2011
# Josh Willingham 2014  Josh Willingham 2014
# Lance Berkman 2013      Lance Berkman 2013
# Mark DeRosa 2013          Mark DeRosa 2013
# Mark Ellis 2014            Mark Ellis 2014
#
# [10 rows x 59 columns]

# %%
#Removing those retired players seen above
master_df= master_df.drop(retired_players.index)

# %%
list(master_df[master_df.DOLLARS=="Minor Lg"]["PLAYER_YEAR"])
#None now, we should have all numbers in this column
# Out:
# []

# %%
'''
Now convert all numbers available to numeric
'''
master_df = master_df.apply(pd.to_numeric,errors='ignore')
master_df.dtypes
# Out:
# PA_x              int64
# BB%             float64
# K%              float64
# BB/K            float64
# AVG_x           float64
# OBP             float64
# SLG             float64
# OPS             float64
# ISO             float64
# Spd             float64
# BABIP           float64
# UBR             float64
# wGDP            float64
# wSB             float64
# wRC               int64
# wRAA            float64
# wOBA            float64
# wRC+              int64
# G                 int64
# AB                int64
# PA_y              int64
# H                 int64
# 1B                int64
# 2B                int64
# 3B                int64
# HR                int64
# R                 int64
# RBI               int64
# BB                int64
# IBB               int64
# SO                int64
# HBP               int64
# SF                int64
# SH                int64
# GDP               int64
# SB                int64
# CS                int64
# AVG_y           float64
# Batting         float64
# Base Running    float64
# Fielding         object
# Positional      float64
# Offense         float64
# Defense         float64
# League          float64
# Replacement     float64
# RAR             float64
# WAR             float64
# Dollars          object
# PLAYER           object
# POS              object
# AGE               int64
# STATUS           object
# OLD_TEAM         object
# NEW_TEAM         object
# YRS             float64
# RK               object
# DOLLARS         float64
# PLAYER_YEAR      object
# dtype: object

# %%
#Replace $ or Commas in DOLLARS with blank
master_df["Dollars"] = master_df["Dollars"].str.replace("(","-")
master_df["Dollars"] = master_df["Dollars"].str.replace(")","")
master_df = master_df.apply(pd.to_numeric,errors='ignore')

# %%
master_df["Fielding"] = master_df["Fielding"].apply(pd.to_numeric,errors='force')

# %%
master_df.dtypes
# Out:
# PA_x              int64
# BB%             float64
# K%              float64
# BB/K            float64
# AVG_x           float64
# OBP             float64
# SLG             float64
# OPS             float64
# ISO             float64
# Spd             float64
# BABIP           float64
# UBR             float64
# wGDP            float64
# wSB             float64
# wRC               int64
# wRAA            float64
# wOBA            float64
# wRC+              int64
# G                 int64
# AB                int64
# PA_y              int64
# H                 int64
# 1B                int64
# 2B                int64
# 3B                int64
# HR                int64
# R                 int64
# RBI               int64
# BB                int64
# IBB               int64
# SO                int64
# HBP               int64
# SF                int64
# SH                int64
# GDP               int64
# SB                int64
# CS                int64
# AVG_y           float64
# Batting         float64
# Base Running    float64
# Fielding        float64
# Positional      float64
# Offense         float64
# Defense         float64
# League          float64
# Replacement     float64
# RAR             float64
# WAR             float64
# Dollars         float64
# PLAYER           object
# POS              object
# AGE               int64
# STATUS           object
# OLD_TEAM         object
# NEW_TEAM         object
# YRS             float64
# RK               object
# DOLLARS         float64
# PLAYER_YEAR      object
# dtype: object

# %%
master_df[['Batting',
       'Base Running', 'Fielding', 'Positional', 'Offense', 'Defense',
       'League', 'Replacement', 'RAR', 'WAR', 'Dollars', ]]
# Out:
#                           Batting  Base Running  Fielding  Positional  \
# PLAYER_YEAR
# Jim Thome 2010               30.8          -4.7       NaN        -8.4
# J.D. Martinez 2017           40.9          -5.8      -8.2        -5.4
# Victor Martinez 2014         47.6          -7.6      -4.0       -14.7
# Franklin Gutierrez 2015      14.7          -0.1       2.9        -2.2
# Paul Konerko 2010            43.2          -5.2     -14.0       -11.9
# Michael Cuddyer 2014         11.5           0.5      -1.7        -2.2
# Prince Fielder 2011          48.1          -7.6      -5.0       -12.3
# Ryan Raburn 2015             12.3           0.4      -1.6        -4.8
# Jayson Werth 2010            35.7           6.1      -7.0        -5.7
# Shin-Soo Choo 2013           40.2           2.2      -6.3         2.1
# Zack Cozart 2017             26.7          -1.5       4.0         4.9
# Adrian Beltre 2010           30.3          -3.4      10.4         2.3
# Carlos Beltran 2011          36.2           0.6      -8.3        -6.3
# Chris Davis 2015             37.9          -0.7       3.9       -11.8
# Melky Cabrera 2012           30.4           3.1      -0.6        -5.0
# Aubrey Huff 2010             35.1           1.1       8.3        -9.6
# Albert Pujols 2011           35.2          -6.4      -0.8       -10.7
# Josh Hamilton 2012           30.7           4.8      -8.2        -2.4
# Robinson Cano 2013           33.6          -4.5       1.9         1.7
# Manny Ramirez 2010           15.4          -3.8      -5.9        -5.0
# Adam Dunn 2010               27.9          -4.3      -3.4       -10.9
# Jose Reyes 2011              28.3           6.7      -3.3         5.6
# Jonny Gomes 2012             16.4           1.7      -0.4        -7.1
# Eric Hosmer 2017             29.0           1.9      -0.8       -12.0
# Jack Cust 2010               18.0          -1.4       0.3       -10.3
# Edwin Encarnacion 2016       29.4          -2.3       1.0       -14.7
# Magglio Ordonez 2010         14.1          -0.4       1.2        -4.5
# Matt Joyce 2016              12.9          -1.0      -0.4        -2.5
# Aramis Ramirez 2011          24.6          -4.7      -9.3         1.8
# Dioner Navarro 2013          11.7          -2.8      -1.1         3.6
# ...                           ...           ...       ...         ...
# Alexi Casilla 2013           -6.9           1.9       0.9         0.3
# Henry Blanco 2010            -8.3           0.0       3.9         3.1
# Cesar Izturis 2010          -32.8           0.0       5.4         6.4
# Alexi Amarista 2016          -8.6          -0.7      -1.5         0.4
# Ben Revere 2016             -24.7           0.7       2.3         0.3
# Dioner Navarro 2010          -8.2          -3.2       0.1         2.8
# Sam Fuld 2013               -10.7           1.4      -0.4        -1.7
# Jason Michaels 2011          -9.7          -0.1       0.4        -1.3
# Nate Schierholtz 2014       -20.5           0.0       3.4        -3.9
# Clint Barmes 2013           -17.5           0.7      -0.9         4.1
# David Adams 2013             -9.3          -0.1       3.2         0.3
# Casey McGehee 2015          -14.4          -5.2      -2.0        -0.6
# Andres Blanco 2017          -10.4           0.8       0.7         0.1
# Wil Nieves 2010             -11.8          -0.8       1.5         3.4
# Gerald Laird 2014            -9.5          -1.4      -0.1         3.2
# Koyie Hill 2011             -10.3          -1.1      -1.1         3.0
# Jason Bay 2012              -12.9           1.8      -1.6        -2.4
# Brendan Ryan 2013           -21.0          -0.5       6.4         4.2
# Stephen Drew 2014           -18.2          -2.4       1.5         2.5
# Jamey Carroll 2013          -16.3          -0.6       1.5         0.8
# Pedro Feliz 2010            -30.8           0.0      -5.0         0.6
# Brian Schneider 2011        -10.3          -3.1      -2.8         2.6
# Cesar Izturis 2013           -9.8          -0.1       2.9         1.0
# Jose Lobaton 2017           -13.0           0.0      -2.0         3.2
# Leonys Martin 2017          -11.1           0.2       3.3        -0.5
# Henry Blanco 2013           -11.2          -0.7      -0.5         3.2
# Jeff Mathis 2015             -8.2           0.5      -1.0         2.1
# Ryan Hanigan 2016           -10.6          -0.1       0.0         2.2
# Chris Stewart 2017          -14.4           0.2       0.0         3.0
# Arismendy Alcantara 2017    -13.0           0.9       1.5         0.1
#
#                           Offense  Defense  League  Replacement   RAR  WAR  \
# PLAYER_YEAR
# Jim Thome 2010               26.1     -8.4     1.5         10.1  29.3  3.0
# J.D. Martinez 2017           35.1    -13.6     1.2         15.1  37.9  3.8
# Victor Martinez 2014         40.0    -18.7     2.1         18.1  41.5  4.6
# Franklin Gutierrez 2015      14.7      0.7     0.6          5.5  21.5  2.3
# Paul Konerko 2010            38.0    -26.0     2.9         18.7  33.6  3.5
# Michael Cuddyer 2014         12.0     -3.9     0.4          5.8  14.3  1.6
# Prince Fielder 2011          40.5    -17.3     1.4         20.1  44.7  4.7
# Ryan Raburn 2015             12.7     -6.4     0.6          5.9  12.8  1.4
# Jayson Werth 2010            41.7    -12.7     1.0         19.3  49.3  5.1
# Shin-Soo Choo 2013           42.4     -4.2     1.1         20.3  59.7  6.4
# Zack Cozart 2017             25.3      8.9     0.7         15.7  50.5  5.0
# Adrian Beltre 2010           26.9     12.7     2.9         19.0  61.5  6.4
# Carlos Beltran 2011          36.8    -14.5     1.2         17.4  40.9  4.3
# Chris Davis 2015             37.2     -7.9     2.2         19.6  51.0  5.4
# Melky Cabrera 2012           33.4     -5.6     0.7         14.8  43.3  4.5
# Aubrey Huff 2010             36.2     -1.3     1.0         19.8  55.7  5.8
# Albert Pujols 2011           28.8    -11.6     1.3         18.9  37.5  4.0
# Josh Hamilton 2012           35.5    -10.6     2.2         18.8  45.8  4.8
# Robinson Cano 2013           29.1      3.6     2.5         19.5  54.5  5.9
# Manny Ramirez 2010           11.6    -10.9     0.7          9.5  10.9  1.1
# Adam Dunn 2010               23.5    -14.3     1.0         19.2  29.3  3.0
# Jose Reyes 2011              34.9      2.3     1.2         17.0  55.4  5.9
# Jonny Gomes 2012             18.1     -7.5     1.1          9.8  21.6  2.3
# Eric Hosmer 2017             30.9    -12.8     2.4         20.7  41.2  4.1
# Jack Cust 2010               16.6     -9.9     1.9         12.6  21.1  2.2
# Edwin Encarnacion 2016       27.1    -13.7     2.5         21.2  37.1  3.8
# Magglio Ordonez 2010         13.6     -3.3     1.7         10.8  22.8  2.4
# Matt Joyce 2016              11.9     -2.9     0.5          8.8  18.3  1.9
# Aramis Ramirez 2011          19.9     -7.5     1.3         18.2  31.9  3.4
# Dioner Navarro 2013           8.8      2.5     0.4          7.6  19.4  2.1
# ...                           ...      ...     ...          ...   ...  ...
# Alexi Casilla 2013           -5.0      1.3     0.5          3.6   0.3  0.0
# Henry Blanco 2010            -8.3      7.0     0.2          4.3   3.2  0.3
# Cesar Izturis 2010          -32.8     11.8     2.3         15.2  -3.5 -0.4
# Alexi Amarista 2016          -9.3     -1.0     0.3          4.5  -5.5 -0.6
# Ben Revere 2016             -24.0      2.6     0.7         11.3  -9.4 -1.0
# Dioner Navarro 2010         -11.4      2.9     0.6          4.2  -3.6 -0.4
# Sam Fuld 2013                -9.4     -2.1     0.7          5.7  -5.0 -0.5
# Jason Michaels 2011          -9.8     -0.9     0.3          4.9  -5.5 -0.6
# Nate Schierholtz 2014       -20.4     -0.5     0.7         10.8  -9.4 -1.0
# Clint Barmes 2013           -16.8      3.3     0.5          9.4  -3.5 -0.4
# David Adams 2013             -9.4      3.5     0.5          4.3  -1.0 -0.1
# Casey McGehee 2015          -19.6     -2.5     0.5          7.5 -14.1 -1.5
# Andres Blanco 2017           -9.6      0.8     0.2          4.5  -4.1 -0.4
# Wil Nieves 2010             -12.5      4.9     0.3          5.1  -2.3 -0.2
# Gerald Laird 2014           -11.0      3.1     0.3          4.7  -2.8 -0.3
# Koyie Hill 2011             -11.4      1.9     0.3          4.4  -4.7 -0.5
# Jason Bay 2012              -11.1     -3.9     0.3          6.4  -8.4 -0.9
# Brendan Ryan 2013           -21.5     10.6     1.3         10.0   0.3  0.0
# Stephen Drew 2014           -20.5      4.0     1.0          8.5  -7.1 -0.8
# Jamey Carroll 2013          -16.9      2.3     0.9          7.1  -6.6 -0.7
# Pedro Feliz 2010            -30.7     -4.4     0.6         12.7 -21.8 -2.3
# Brian Schneider 2011        -13.4     -0.2     0.3          4.0  -9.2 -1.0
# Cesar Izturis 2013           -9.9      3.9     0.2          4.1  -1.7 -0.2
# Jose Lobaton 2017           -13.0      1.2     0.2          4.9  -6.6 -0.7
# Leonys Martin 2017          -10.8      2.8     0.5          4.3  -3.3 -0.3
# Henry Blanco 2013           -11.9      2.7     0.5          4.3  -4.4 -0.5
# Jeff Mathis 2015             -7.7      1.1     0.2          3.0  -3.4 -0.4
# Ryan Hanigan 2016           -10.8      2.2     0.4          3.4  -4.8 -0.5
# Chris Stewart 2017          -14.2      3.0     0.2          4.5  -6.5 -0.6
# Arismendy Alcantara 2017    -12.1      1.6     0.2          3.3  -7.0 -0.7
#
#                           Dollars
# PLAYER_YEAR
# Jim Thome 2010               18.2
# J.D. Martinez 2017           30.2
# Victor Martinez 2014         34.6
# Franklin Gutierrez 2015      18.2
# Paul Konerko 2010            20.9
# Michael Cuddyer 2014         11.9
# Prince Fielder 2011          35.9
# Ryan Raburn 2015             10.9
# Jayson Werth 2010            30.7
# Shin-Soo Choo 2013           47.7
# Zack Cozart 2017             40.2
# Adrian Beltre 2010           38.3
# Carlos Beltran 2011          32.9
# Chris Davis 2015             43.3
# Melky Cabrera 2012           29.5
# Aubrey Huff 2010             34.6
# Albert Pujols 2011           30.1
# Josh Hamilton 2012           31.2
# Robinson Cano 2013           43.6
# Manny Ramirez 2010            6.8
# Adam Dunn 2010               18.2
# Jose Reyes 2011              44.6
# Jonny Gomes 2012             14.7
# Eric Hosmer 2017             32.8
# Jack Cust 2010               13.2
# Edwin Encarnacion 2016       30.3
# Magglio Ordonez 2010         14.2
# Matt Joyce 2016              15.0
# Aramis Ramirez 2011          25.6
# Dioner Navarro 2013          15.5
# ...                           ...
# Alexi Casilla 2013            0.2
# Henry Blanco 2010             2.0
# Cesar Izturis 2010           -2.2
# Alexi Amarista 2016          -4.5
# Ben Revere 2016              -7.7
# Dioner Navarro 2010          -2.3
# Sam Fuld 2013                -4.0
# Jason Michaels 2011          -4.4
# Nate Schierholtz 2014        -7.8
# Clint Barmes 2013            -2.8
# David Adams 2013             -0.8
# Casey McGehee 2015          -12.0
# Andres Blanco 2017           -3.3
# Wil Nieves 2010              -1.4
# Gerald Laird 2014            -2.3
# Koyie Hill 2011              -3.8
# Jason Bay 2012               -5.7
# Brendan Ryan 2013             0.3
# Stephen Drew 2014            -5.9
# Jamey Carroll 2013           -5.3
# Pedro Feliz 2010            -13.6
# Brian Schneider 2011         -7.4
# Cesar Izturis 2013           -1.4
# Jose Lobaton 2017            -5.3
# Leonys Martin 2017           -2.6
# Henry Blanco 2013            -3.5
# Jeff Mathis 2015             -2.9
# Ryan Hanigan 2016            -3.9
# Chris Stewart 2017           -5.2
# Arismendy Alcantara 2017     -5.6
#
# [516 rows x 11 columns]

# %%
master_df.rename({"Dollars":"Fangraphs_Dollars"}, axis='columns',inplace=True)

# %%
master_df[["BB%","K%"]].head()
# Out:
#                           BB%    K%
# PLAYER_YEAR
# Jim Thome 2010           17.6  24.1
# J.D. Martinez 2017       10.8  26.2
# Victor Martinez 2014     10.9   6.6
# Franklin Gutierrez 2015   7.4  28.6
# Paul Konerko 2010        11.4  17.4

# %% [markdown]
# ## First Clean - Finished

# %%
#Save progress
with open('master_df_42418.pkl', 'wb') as picklefile:
    pickle.dump(master_df, picklefile)

# %%
#Let's Make a $/Year Column - contract values need to be yearly to be standard
master_df["DOLLARS_PER_YEAR"]=master_df["DOLLARS"].astype(float)/master_df["YRS"].astype(float)

# %%
master_df.sort_values(by="DOLLARS_PER_YEAR",ascending=False).head(10) 
#This Looks Good
#Yo,Pujols, Cano, Hamilton all signed MONSTER deals so this looks right
# Out:
#                       PA_x   BB%    K%  BB/K  AVG_x    OBP    SLG    OPS  \
# PLAYER_YEAR
# Yoenis Cespedes 2016   543   9.4  19.9  0.47  0.280  0.354  0.530  0.884
# Yoenis Cespedes 2015   676   4.9  20.9  0.23  0.291  0.328  0.542  0.870
# Albert Pujols 2011     651   9.4   8.9  1.05  0.299  0.366  0.541  0.906
# Josh Hamilton 2012     636   9.4  25.5  0.37  0.285  0.354  0.577  0.930
# Robinson Cano 2013     681   9.5  12.5  0.76  0.314  0.383  0.516  0.899
# Prince Fielder 2011    692  15.5  15.3  1.01  0.299  0.415  0.566  0.981
# Chris Davis 2015       670  12.5  31.0  0.40  0.262  0.361  0.562  0.923
# Jason Heyward 2015     610   9.2  14.8  0.62  0.293  0.359  0.439  0.797
# Justin Upton 2015      620  11.0  25.6  0.43  0.251  0.336  0.454  0.790
# J.D. Martinez 2017     489  10.8  26.2  0.41  0.303  0.376  0.690  1.066
#
#                         ISO  Spd        ...         POS  AGE      STATUS  \
# PLAYER_YEAR                             ...
# Yoenis Cespedes 2016  0.251  2.9        ...          LF   32      Signed
# Yoenis Cespedes 2015  0.251  5.1        ...          LF   32      Signed
# Albert Pujols 2011    0.242  3.9        ...          DH   38  Signed (A)
# Josh Hamilton 2012    0.292  4.0        ...          LF   36      Signed
# Robinson Cano 2013    0.202  2.9        ...          2B   35      Signed
# Prince Fielder 2011   0.267  1.9        ...          DH   33  Signed (A)
# Chris Davis 2015      0.300  1.9        ...          1B   32      Signed
# Jason Heyward 2015    0.146  6.0        ...          RF   28      Signed
# Justin Upton 2015     0.203  5.7        ...          LF   30      Signed
# J.D. Martinez 2017    0.387  4.7        ...          RF   30      Signed
#
#                           OLD_TEAM  NEW_TEAM   YRS  RK      DOLLARS  \
# PLAYER_YEAR
# Yoenis Cespedes 2016          Mets      Mets   4.0   1  110000000.0
# Yoenis Cespedes 2015          Mets      Mets   3.0   5   75000000.0
# Albert Pujols 2011       Cardinals    Angels  10.0   2  250000000.0
# Josh Hamilton 2012         Rangers    Angels   5.0   3  123000000.0
# Robinson Cano 2013         Yankees  Mariners  10.0   1  240000000.0
# Prince Fielder 2011        Brewers    Tigers   9.0   1  214000000.0
# Chris Davis 2015           Orioles   Orioles   7.0   7  161000000.0
# Jason Heyward 2015       Cardinals      Cubs   8.0   1  184000000.0
# Justin Upton 2015           Padres    Tigers   6.0   4  132750000.0
# J.D. Martinez 2017    Diamondbacks   Red Sox   5.0   6  110000000.0
#
#                                PLAYER_YEAR  DOLLARS_PER_YEAR
# PLAYER_YEAR
# Yoenis Cespedes 2016  Yoenis Cespedes 2016      2.750000e+07
# Yoenis Cespedes 2015  Yoenis Cespedes 2015      2.500000e+07
# Albert Pujols 2011      Albert Pujols 2011      2.500000e+07
# Josh Hamilton 2012      Josh Hamilton 2012      2.460000e+07
# Robinson Cano 2013      Robinson Cano 2013      2.400000e+07
# Prince Fielder 2011    Prince Fielder 2011      2.377778e+07
# Chris Davis 2015          Chris Davis 2015      2.300000e+07
# Jason Heyward 2015      Jason Heyward 2015      2.300000e+07
# Justin Upton 2015        Justin Upton 2015      2.212500e+07
# J.D. Martinez 2017      J.D. Martinez 2017      2.200000e+07
#
# [10 rows x 60 columns]

# %%
master_df.dtypes #Looks Good
# Out:
# PA_x                   int64
# BB%                  float64
# K%                   float64
# BB/K                 float64
# AVG_x                float64
# OBP                  float64
# SLG                  float64
# OPS                  float64
# ISO                  float64
# Spd                  float64
# BABIP                float64
# UBR                  float64
# wGDP                 float64
# wSB                  float64
# wRC                    int64
# wRAA                 float64
# wOBA                 float64
# wRC+                   int64
# G                      int64
# AB                     int64
# PA_y                   int64
# H                      int64
# 1B                     int64
# 2B                     int64
# 3B                     int64
# HR                     int64
# R                      int64
# RBI                    int64
# BB                     int64
# IBB                    int64
# SO                     int64
# HBP                    int64
# SF                     int64
# SH                     int64
# GDP                    int64
# SB                     int64
# CS                     int64
# AVG_y                float64
# Batting              float64
# Base Running         float64
# Fielding             float64
# Positional           float64
# Offense              float64
# Defense              float64
# League               float64
# Replacement          float64
# RAR                  float64
# WAR                  float64
# Fangraphs_Dollars    float64
# PLAYER                object
# POS                   object
# AGE                    int64
# STATUS                object
# OLD_TEAM              object
# NEW_TEAM              object
# YRS                  float64
# RK                    object
# DOLLARS              float64
# PLAYER_YEAR           object
# DOLLARS_PER_YEAR     float64
# dtype: object

# %%
master_df["POS"].loc[master_df[master_df["POS"]=="OF"].index] = "LF"
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
master_df["POS"].unique()
# Out:
# array(['DH', 'RF', 'LF', '3B', '1B', '2B', 'SS', 'C', 'CF', 'SP'],
#       dtype=object)

# %%
#Drop Null Values
#Drop Pitchers
master_df = master_df.drop(master_df[master_df.isnull().values].index)
master_df = master_df.drop(master_df[master_df["POS"]=="SP"].index)

# %%
#Drop AVG_y Column since AVG_x is the same number
master_df=master_df.drop(["AVG_y"],1)

# %%
master_df["PA_x"] = master_df["PA_x"].apply(pd.to_numeric,errors='ignore')

# %%
master_df.dtypes
# Out:
# PA_x                   int64
# BB%                  float64
# K%                   float64
# BB/K                 float64
# AVG_x                float64
# OBP                  float64
# SLG                  float64
# OPS                  float64
# ISO                  float64
# Spd                  float64
# BABIP                float64
# UBR                  float64
# wGDP                 float64
# wSB                  float64
# wRC                    int64
# wRAA                 float64
# wOBA                 float64
# wRC+                   int64
# G                      int64
# AB                     int64
# PA_y                   int64
# H                      int64
# 1B                     int64
# 2B                     int64
# 3B                     int64
# HR                     int64
# R                      int64
# RBI                    int64
# BB                     int64
# IBB                    int64
# SO                     int64
# HBP                    int64
# SF                     int64
# SH                     int64
# GDP                    int64
# SB                     int64
# CS                     int64
# Batting              float64
# Base Running         float64
# Fielding             float64
# Positional           float64
# Offense              float64
# Defense              float64
# League               float64
# Replacement          float64
# RAR                  float64
# WAR                  float64
# Fangraphs_Dollars    float64
# PLAYER                object
# POS                   object
# AGE                    int64
# STATUS                object
# OLD_TEAM              object
# NEW_TEAM              object
# YRS                  float64
# RK                    object
# DOLLARS              float64
# PLAYER_YEAR           object
# DOLLARS_PER_YEAR     float64
# dtype: object

# %%
#Save progress
with open('master_df_42418.pkl', 'wb') as picklefile:
    pickle.dump(master_df, picklefile)
