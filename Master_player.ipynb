# %%
import pickle

master_player = pickle.load( open( "master_players_2.pkl", "rb" ) )

# %%
import pandas as pd
import numpy as np
import seaborn

# %%
# master_player
master_player["Howie Kendrick 2017"]
# Out:
# ['-',
#  '-',
#  '-',
#  '91',
#  '305',
#  '334',
#  '96',
#  '68',
#  '16',
#  '3',
#  '9',
#  '40',
#  '41',
#  '22',
#  '0',
#  '68',
#  '5',
#  '2',
#  '0',
#  '8',
#  '12',
#  '5',
#  '.315',
#  ['-',
#   '-',
#   '-',
#   '334',
#   '6.6',
#   '20.4',
#   '0.32',
#   '.315',
#   '.368',
#   '.475',
#   '.844',
#   '.161',
#   '5.7',
#   '.378',
#   '-0.4',
#   '-0.6',
#   '0.0',
#   '52',
#   '11.4',
#   '.361',
#   '121'],
#  ['-',
#   '-',
#   '-',
#   '.378',
#   '2.85',
#   '21.9',
#   '57.8',
#   '20.3',
#   '2.1',
#   '18.8',
#   '9',
#   '6.6',
#   '2',
#   '100.0',
#   '31.4',
#   '38.9',
#   '29.7',
#   '17.2',
#   '51.5',
#   '31.4'],
#  ['-',
#   '-',
#   '-',
#   '-0.41',
#   '-6.21',
#   '5.80',
#   '12.52',
#   '1.27',
#   '1.02',
#   '1.19',
#   '15',
#   '0.88',
#   '-1.28'],
#  ['-',
#   '-',
#   '-',
#   '58.1',
#   '92.9',
#   '18.4',
#   '84.4',
#   '6.2',
#   '88.6',
#   '7.9',
#   '79.4',
#   '8.5',
#   '84.6',
#   '0.6',
#   '82.4',
#   '0.4',
#   '74.6',
#   '',
#   ''],
#  ['-',
#   '-',
#   '-',
#   '3.6',
#   '3.5',
#   '-0.3',
#   '-0.8',
#   '3.9',
#   '1.4',
#   '-0.8',
#   '0.47',
#   '1.44',
#   '-0.36',
#   '-0.74',
#   '3.55',
#   '17.06',
#   '-15.13'],
#  ['-',
#   '-',
#   '-',
#   '33.5',
#   '64.8',
#   '47.8',
#   '67.4',
#   '87.6',
#   '79.9',
#   '45.6',
#   '62.6',
#   '9.6'],
#  ['-',
#   '-',
#   '-',
#   '9.0',
#   '-1.0',
#   '0.5',
#   '-2.5',
#   '8.1',
#   '-2.0',
#   '0.5',
#   '10.3',
#   '16.9',
#   '1.7',
#   '$13.4']]

# %%
df1 = pd.DataFrame.from_dict(master_player, orient='index')
df1.transpose()
df1.loc["Howie Kendrick 2017"]
# Out:
# 0                                                     -
# 1                                                     -
# 2                                                     -
# 3                                                    91
# 4                                                   305
# 5                                                   334
# 6                                                    96
# 7                                                    68
# 8                                                    16
# 9                                                     3
# 10                                                    9
# 11                                                   40
# 12                                                   41
# 13                                                   22
# 14                                                    0
# 15                                                   68
# 16                                                    5
# 17                                                    2
# 18                                                    0
# 19                                                    8
# 20                                                   12
# 21                                                    5
# 22                                                 .315
# 23    [-, -, -, 334, 6.6, 20.4, 0.32, .315, .368, .4...
# 24    [-, -, -, .378, 2.85, 21.9, 57.8, 20.3, 2.1, 1...
# 25    [-, -, -, -0.41, -6.21, 5.80, 12.52, 1.27, 1.0...
# 26    [-, -, -, 58.1, 92.9, 18.4, 84.4, 6.2, 88.6, 7...
# 27    [-, -, -, 3.6, 3.5, -0.3, -0.8, 3.9, 1.4, -0.8...
# 28    [-, -, -, 33.5, 64.8, 47.8, 67.4, 87.6, 79.9, ...
# 29    [-, -, -, 9.0, -1.0, 0.5, -2.5, 8.1, -2.0, 0.5...
# 30                                                 None
# Name: Howie Kendrick 2017, dtype: object

# %%
#Before cleaning, I'd think it's more valuable to join in Free Agents
#Save me the trouble of cleaning random players we wont need
# df1.loc["Eric Hosmer 2017"] matches my ESPN Dataset! woo - so does JD Martinez

import pickle

with open('master_players_dataframe_2.pkl', 'wb') as picklefile:
    pickle.dump(df1, picklefile)
