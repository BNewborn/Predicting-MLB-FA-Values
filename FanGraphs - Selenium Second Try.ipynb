# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import os

chromedriver = "/Users/brian_newborn/Downloads/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver
driver = webdriver.Chrome(chromedriver)
# url="https://www.fangraphs.com/leaders.aspx?pos=all&stats=bat&lg=all&qual=100&type=0&season=2017&month=0&season1=2017&ind=0&team=0&rost=0&age=0&filter=&players=0"
url="https://www.fangraphs.com/leaders.aspx?pos=all&stats=bat&lg=all&qual=100&type=0&season=2017&month=0&season1=2010&ind=1&team=0&rost=0&age=0&filter=&players=0"
driver.get(url)

#Need to Save Column Names
col_names_list = []
master_players={}

# %%
# # # #troubleshooting
# # next_section= driver.find_elements_by_xpath\
# # ('.//div[@class = "rtsLevel rtsLevel1"]//li[@class="rtsLI"]//a[@class = "rtsLink rtsAfter"]')
# # next_section_sp = next_section[3]
# # print(f"Next Section: {next_section_sp.text}")

# # current_page_like_headers = driver.find_elements_by_xpath('//a[@class="rtsLink rtsSelected"]//span[@class="rtsTxt"]')
# # current_page = current_page_like_headers[3].text
# # print(f"Current Page: {current_page}")
# # identifier_header = "rgHeader"
# # col_names = driver.find_elements_by_class_name(identifier_header)
    
# # for n in col_names:
# #     if n.text not in col_names_list:
# # #         col_names_list.append(n.text)  
# #         print(n.text, "| not in col")
# #     else:
# #         print("in list |", n.text)
        
# # driver.find_element_by_xpath('.//div[@class = "rgWrap rgNumPart"]//a[@class="rgCurrentPage"]').text
            
# identifier1,identifier2 = "rgRow","rgAltRow"

# players = driver.find_elements_by_class_name(identifier2)
# players2 = driver.find_elements_by_class_name(identifier1)
# players = players+ players2
    
# for player in players[1:10]:
#     player = str(player.text)
#     player=player.replace(" %","")
#     player = player.split(' ')
#     name = player[2]+' '+player[3]+' '+player[1]
#     print(player)
#     if name in master_players:
#         master_players[name].append(player[4:])
#     else:
#         master_players[name]=player[4:]
# master_players

# # identifier_header = "rgHeader"
    
# # col_names = driver.find_elements_by_class_name(identifier_header)
# # curr_page = driver.find_element_by_xpath\
# # ('.//div[@class = "rgWrap rgNumPart"]//a[@class="rgCurrentPage"]').text
# # if int(curr_page) == 1:
# #     for n in col_names:
# #         col_names_list.append(n.text) 
# # col_names_list

# %%
def next_pg():
    next_section_sp =''
    #Then, try next page button - we want all names within a section
    try:
        next_pg = driver.find_element_by_xpath('//a[@title="Next Page"]')
        next_pg.send_keys(u'\ue007')
        
        
    except: #End of Section, go to next section
        print("End of Section")
        next_section= driver.find_elements_by_xpath\
        ('.//div[@class = "rtsLevel rtsLevel1"]//li[@class="rtsLI"]//a[@class = "rtsLink rtsAfter"]')
        next_section_sp = next_section[3]
        print(f"Next Section: {next_section_sp.text}")
        next_section_sp.send_keys(u'\ue007')
    return next_section_sp

def scrape_players():
    #Grab Headers - if they arent in list
    identifier_header = "rgHeader"
    
    col_names = driver.find_elements_by_class_name(identifier_header)
    curr_page = driver.find_element_by_xpath\
    ('.//div[@class = "rgWrap rgNumPart"]//a[@class="rgCurrentPage"]').text
    if int(curr_page) == 1:
        for n in col_names[4:]:
            col_names_list.append(n.text) 
            
    
    #Grab Players - 2 Types of HTML rows
    identifier1,identifier2 = "rgRow","rgAltRow"

    players = driver.find_elements_by_class_name(identifier2)
    players2 = driver.find_elements_by_class_name(identifier1)
    players = players+ players2
    
    for player in players:
        player = str(player.text)
        player=player.replace(" %","")
        player = player.split(' ')
        name =  player[2]+' '+player[3]+' '+player[1]
    
        if name in master_players:
            master_players[name].append(player[4:])
        else:
            master_players[name]=player[4:]

# %%
keep_running = True #flag to keep loop going
while keep_running == True:
    #grab current page title from next_pg function
    curr_page = next_pg()
    #if that curr_page var = Pitch Info, kill the program
    if curr_page == 'Pitch Info':
        break
    #then scrape players, if we're on the right page
    scrape_players()
#     print(f"Current Page: {curr_page}")
# Out:
# End of Section
# Next Section: Batted Ball
# End of Section
# Next Section: Win Probability
# End of Section
# Next Section: Pitch Type
# End of Section
# Next Section: Pitch Value
# End of Section
# Next Section: Plate Discipline
# End of Section
# Next Section: Value
# End of Section
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-96-03423f18adb3> in next_pg()
#       5         next_pg = driver.find_element_by_xpath('//a[@title="Next Page"]')
# ----> 6         next_pg.send_keys(u'\ue007')
#       7
#
# /anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in send_keys(self, *value)
#     351                       {'text': "".join(keys_to_typing(value)),
# --> 352                        'value': keys_to_typing(value)})
#     353
#
# /anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     500         params['id'] = self._id
# --> 501         return self._parent.execute(command, params)
#     502
#
# /anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     307         if response:
# --> 308             self.error_handler.check_response(response)
#     309             response['value'] = self._unwrap_value(
#
# /anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     193             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 194         raise exception_class(message, screen, stacktrace)
#     195
#
# WebDriverException: Message: unknown error: cannot focus element
#   (Session info: chrome=65.0.3325.181)
#   (Driver info: chromedriver=2.37.544337 (8c0344a12e552148c185f7d5117db1f28d6c9e85),platform=Mac OS X 10.13.4 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-99-de09244193b9> in <module>()
#       2 while keep_running == True:
#       3     #grab current page title from next_pg function
# ----> 4     curr_page = next_pg()
#       5     #if that curr_page var = Pitch Info, kill the program
#       6     if curr_page == 'Pitch Info':
#
# <ipython-input-96-03423f18adb3> in next_pg()
#      10         print("End of Section")
#      11         next_section= driver.find_elements_by_xpath        ('.//div[@class = "rtsLevel rtsLevel1"]//li[@class="rtsLI"]//a[@class = "rtsLink rtsAfter"]')
# ---> 12         next_section_sp = next_section[3]
#      13         print(f"Next Section: {next_section_sp.text}")
#      14         next_section_sp.send_keys(u'\ue007')
#
# IndexError: list index out of range

# %%
master_players
# Out:
# {'Adam Lind 2014': ['Blue',
#   'Jays',
#   '96',
#   '290',
#   '318',
#   '93',
#   '61',
#   '24',
#   '2',
#   '6',
#   '38',
#   '40',
#   '28',
#   '3',
#   '48',
#   '0',
#   '0',
#   '0',
#   '8',
#   '0',
#   '0',
#   '.321',
#   ['Blue',
#    'Jays',
#    '318',
#    '8.8',
#    '15.1',
#    '0.58',
#    '.321',
#    '.381',
#    '.479',
#    '.860',
#    '.159',
#    '2.5',
#    '.369',
#    '1.8',
#    '-1.1',
#    '-0.3',
#    '50',
#    '16.1',
#    '.376',
#    '142'],
#   ['Blue',
#    'Jays',
#    '.369',
#    '1.43',
#    '20.7',
#    '46.7',
#    '32.6',
#    '10.1',
#    '7.6',
#    '6',
#    '5.3',
#    '0',
#    '0.0',
#    '31.4',
#    '37.2',
#    '31.4',
#    '14.1',
#    '48.8',
#    '37.2'],
#   ['Blue',
#    'Jays',
#    '0.58',
#    '-5.50',
#    '6.08',
#    '21.06',
#    '2.23',
#    '0.97',
#    '1.47',
#    '16',
#    '1.17',
#    '-0.57'],
#   ['Blue',
#    'Jays',
#    '62.5',
#    '92.4',
#    '9.1',
#    '83.6',
#    '5.8',
#    '88.4',
#    '10.3',
#    '78.1',
#    '9.0',
#    '85.0',
#    '2.7',
#    '84.3',
#    '0.7',
#    '73.3',
#    '1.0'],
#   ['Blue',
#    'Jays',
#    '4.3',
#    '5.3',
#    '2.4',
#    '-0.8',
#    '6.1',
#    '-2.4',
#    '0.9',
#    '0.54',
#    '4.69',
#    '3.26',
#    '-0.63',
#    '5.41',
#    '-7.01',
#    '9.94'],
#   ['Blue',
#    'Jays',
#    '30.0',
#    '64.3',
#    '43.8',
#    '70.8',
#    '89.5',
#    '81.8',
#    '40.1',
#    '52.8',
#    '7.9'],
#   ['Blue',
#    'Jays',
#    '14.8',
#    '0.4',
#    '-2.4',
#    '-7.2',
#    '15.2',
#    '-9.6',
#    '1.0',
#    '9.0',
#    '15.6',
#    '1.7',
#    '$13.0']],
#  'Joey Votto 2017': ['Reds',
#   '162',
#   '559',
#   '707',
#   '179',
#   '108',
#   '34',
#   '1',
#   '36',
#   '106',
#   '100',
#   '134',
#   '20',
#   '83',
#   '8',
#   '6',
#   '0',
#   '16',
#   '5',
#   '1',
#   '.320',
#   ['Reds',
#    '707',
#    '19.0',
#    '11.7',
#    '1.61',
#    '.320',
#    '.454',
#    '.578',
#    '1.032',
#    '.258',
#    '2.8',
#    '.321',
#    '-10.1',
#    '0.5',
#    '0.0',
#    '150',
#    '64.0',
#    '.428',
#    '165'],
#   ['Reds',
#    '.321',
#    '1.03',
#    '23.0',
#    '39.0',
#    '38.0',
#    '0.5',
#    '19.7',
#    '5',
#    '2.7',
#    '0',
#    '0.0',
#    '38.6',
#    '31.1',
#    '30.3',
#    '10.4',
#    '53.3',
#    '36.3'],
#   ['Reds',
#    '4.76',
#    '-9.04',
#    '13.80',
#    '67.49',
#    '6.69',
#    '0.90',
#    '',
#    '',
#    '0',
#    '6.09',
#    '-0.80'],
#   ['Reds',
#    '58.0',
#    '93.1',
#    '12.7',
#    '84.0',
#    '7.0',
#    '88.0',
#    '8.4',
#    '78.2',
#    '12.2',
#    '85.0',
#    '1.1',
#    '84.9',
#    '0.6',
#    '78.5',
#    '2.9'],
#   ['Reds',
#    '37.2',
#    '7.5',
#    '0.6',
#    '8.8',
#    '4.6',
#    '2.3',
#    '0.5',
#    '2.35',
#    '2.15',
#    '0.33',
#    '3.83',
#    '1.39',
#    '7.54',
#    '3.11'],
#   ['Reds',
#    '15.8',
#    '71.4',
#    '41.9',
#    '78.3',
#    '88.0',
#    '86.0',
#    '46.8',
#    '55.9',
#    '5.9'],
#   ['Reds',
#    '58.8',
#    '-9.6',
#    '6.0',
#    '-11.9',
#    '49.2',
#    '-5.9',
#    '1.0',
#    '21.9',
#    '66.1',
#    '6.6',
#    '$52.7']],
#  'Mike Napoli 2011': ['Rangers',
#   '113',
#   '369',
#   '432',
#   '118',
#   '63',
#   '25',
#   '0',
#   '30',
#   '72',
#   '75',
#   '58',
#   '2',
#   '85',
#   '3',
#   '2',
#   '0',
#   '10',
#   '4',
#   '2',
#   '.320',
#   ['Rangers',
#    '432',
#    '13.4',
#    '19.7',
#    '0.68',
#    '.320',
#    '.414',
#    '.631',
#    '1.046',
#    '.312',
#    '2.8',
#    '.344',
#    '-2.2',
#    '-0.2',
#    '-0.4',
#    '93',
#    '44.2',
#    '.445',
#    '179'],
#   ['Rangers',
#    '.344',
#    '0.95',
#    '19.6',
#    '39.2',
#    '41.3',
#    '5.1',
#    '25.4',
#    '7',
#    '6.3',
#    '0',
#    '0.0',
#    '41.3',
#    '33.6',
#    '25.2',
#    '18.9',
#    '46.2',
#    '35.0'],
#   ['Rangers',
#    '1.89',
#    '-6.30',
#    '8.19',
#    '43.47',
#    '4.40',
#    '0.84',
#    '2.06',
#    '7',
#    '3.77',
#    '-1.52'],
#   ['Rangers',
#    '61.0',
#    '91.9',
#    '13.2',
#    '83.7',
#    '7.1',
#    '87.9',
#    '7.4',
#    '77.2',
#    '10.5',
#    '81.5',
#    '0.6',
#    '86.1',
#    '0.2',
#    '67.3',
#    '0.6'],
#   ['Rangers',
#    '26.4',
#    '1.9',
#    '2.7',
#    '6.8',
#    '3.3',
#    '1.6',
#    '-0.2',
#    '2.31',
#    '0.75',
#    '2.05',
#    '4.89',
#    '1.66',
#    '13.65',
#    '-5.09'],
#   ['Rangers',
#    '23.7',
#    '60.2',
#    '40.0',
#    '65.9',
#    '78.7',
#    '74.5',
#    '44.7',
#    '54.9',
#    '10.2'],
#   ['Rangers',
#    '39.5',
#    '-2.8',
#    '0.2',
#    '0.2',
#    '36.7',
#    '0.4',
#    '1.4',
#    '12.6',
#    '51.0',
#    '5.4',
#    '$41.0']],
#  'Daniel Murphy 2011': ['Mets',
#   '109',
#   '391',
#   '423',
#   '125',
#   '89',
#   '28',
#   '2',
#   '6',
#   '49',
#   '49',
#   '24',
#   '2',
#   '42',
#   '3',
#   '2',
#   '3',
#   '14',
#   '5',
#   '5',
#   '.320',
#   ['Mets',
#    '423',
#    '5.7',
#    '9.9',
#    '0.57',
#    '.320',
#    '.362',
#    '.448',
#    '.809',
#    '.128',
#    '3.7',
#    '.345',
#    '0.2',
#    '-1.3',
#    '-1.4',
#    '60',
#    '12.7',
#    '.354',
#    '126'],
#   ['Mets',
#    '.345',
#    '1.51',
#    '21.9',
#    '47.0',
#    '31.1',
#    '9.2',
#    '5.5',
#    '11',
#    '6.7',
#    '0',
#    '0.0',
#    '34.5',
#    '38.1',
#    '27.4',
#    '24.0',
#    '50.6',
#    '25.4'],
#   ['Mets',
#    '0.65',
#    '-7.47',
#    '8.12',
#    '11.52',
#    '1.15',
#    '1.05',
#    '1.24',
#    '19',
#    '0.98',
#    '-0.36'],
#   ['Mets',
#    '62.7',
#    '91.2',
#    '12.2',
#    '82.9',
#    '3.4',
#    '87.4',
#    '8.3',
#    '76.7',
#    '11.5',
#    '82.9',
#    '1.9',
#    '83.8',
#    '',
#    '',
#    '',
#    '',
#    '0.7'],
#   ['Mets',
#    '4.6',
#    '1.8',
#    '1.1',
#    '0.3',
#    '1.2',
#    '1.2',
#    '',
#    '',
#    '0.47',
#    '0.93',
#    '1.99',
#    '0.19',
#    '0.65',
#    '4.11',
#    '',
#    ''],
#   ['Mets',
#    '31.2',
#    '66.7',
#    '45.8',
#    '83.5',
#    '94.0',
#    '89.8',
#    '41.4',
#    '56.7',
#    '4.7'],
#   ['Mets',
#    '12.9',
#    '-2.5',
#    '3.8',
#    '-2.9',
#    '10.4',
#    '0.9',
#    '0.8',
#    '12.3',
#    '24.5',
#    '2.6',
#    '$19.7']],
#  'Robinson Cano 2010': ['Yankees',
#   '160',
#   '626',
#   '696',
#   '200',
#   '127',
#   '41',
#   '3',
#   '29',
#   '103',
#   '109',
#   '57',
#   '14',
#   '77',
#   '8',
#   '5',
#   '0',
#   '19',
#   '3',
#   '2',
#   '.319',
#   ['Yankees',
#    '696',
#    '8.2',
#    '11.1',
#    '0.74',
#    '.319',
#    '.381',
#    '.534',
#    '.914',
#    '.214',
#    '3.2',
#    '.326',
#    '2.9',
#    '-1.3',
#    '-0.8',
#    '119',
#    '39.0',
#    '.391',
#    '143'],
#   ['Yankees',
#    '.326',
#    '1.21',
#    '19.3',
#    '44.2',
#    '36.5',
#    '8.9',
#    '14.4',
#    '11',
#    '4.5',
#    '0',
#    '0.0',
#    '40.6',
#    '34.7',
#    '24.7',
#    '17.3',
#    '47.3',
#    '35.4'],
#   ['Yankees',
#    '4.07',
#    '-9.92',
#    '13.99',
#    '41.37',
#    '4.27',
#    '0.91',
#    '1.89',
#    '1',
#    '4.10',
#    '0.36'],
#   ['Yankees',
#    '57.4',
#    '91.2',
#    '12.1',
#    '82.4',
#    '6.6',
#    '87.1',
#    '9.8',
#    '77.2',
#    '10.8',
#    '82.3',
#    '2.4',
#    '85.6',
#    '0.8',
#    '67.8',
#    '2.7'],
#   ['Yankees',
#    '15.2',
#    '13.5',
#    '-2.0',
#    '6.7',
#    '2.6',
#    '0.5',
#    '1.6',
#    '1.13',
#    '4.73',
#    '-1.27',
#    '2.88',
#    '1.03',
#    '0.89',
#    '9.02'],
#   ['Yankees',
#    '35.6',
#    '73.8',
#    '51.8',
#    '75.1',
#    '94.4',
#    '86.8',
#    '42.4',
#    '58.3',
#    '6.8'],
#   ['Yankees',
#    '34.8',
#    '0.8',
#    '-0.5',
#    '2.2',
#    '35.7',
#    '1.7',
#    '3.1',
#    '20.6',
#    '61.1',
#    '6.3',
#    '$38.0']],
#  'Ryan Braun 2012': ['Brewers',
#   '154',
#   '598',
#   '677',
#   '191',
#   '111',
#   '36',
#   '3',
#   '41',
#   '108',
#   '112',
#   '63',
#   '15',
#   '128',
#   '11',
#   '5',
#   '0',
#   '12',
#   '30',
#   '7',
#   '.319',
#   ['Brewers',
#    '677',
#    '9.3',
#    '18.9',
#    '0.49',
#    '.319',
#    '.391',
#    '.595',
#    '.987',
#    '.276',
#    '5.7',
#    '.346',
#    '-0.1',
#    '0.1',
#    '2.4',
#    '131',
#    '53.4',
#    '.413',
#    '159'],
#   ['Brewers',
#    '.346',
#    '1.14',
#    '18.4',
#    '43.6',
#    '38.1',
#    '6.1',
#    '22.8',
#    '19',
#    '9.2',
#    '1',
#    '50.0',
#    '33.3',
#    '36.6',
#    '30.1',
#    '12.2',
#    '51.0',
#    '36.8'],
#   ['Brewers',
#    '5.03',
#    '-10.07',
#    '15.10',
#    '50.93',
#    '5.39',
#    '0.97',
#    '4.74',
#    '1',
#    '6.03',
#    '-0.87'],
#   ['Brewers',
#    '59.2',
#    '91.8',
#    '16.2',
#    '83.7',
#    '5.8',
#    '87.4',
#    '8.6',
#    '77.8',
#    '9.4',
#    '82.6',
#    '0.7',
#    '83.8',
#    '',
#    '',
#    '',
#    '',
#    '2.0'],
#   ['Brewers',
#    '32.4',
#    '3.7',
#    '4.3',
#    '9.1',
#    '1.5',
#    '-0.9',
#    '',
#    '',
#    '2.20',
#    '0.92',
#    '2.96',
#    '4.22',
#    '0.65',
#    '-5.34',
#    '',
#    ''],
#   ['Brewers',
#    '36.4',
#    '67.6',
#    '49.4',
#    '72.6',
#    '85.7',
#    '80.1',
#    '41.6',
#    '59.5',
#    '9.7'],
#   ['Brewers',
#    '47.9',
#    '2.4',
#    '0.8',
#    '-7.0',
#    '50.4',
#    '-6.2',
#    '1.0',
#    '20.0',
#    '65.1',
#    '6.8',
#    '$44.4']],
#  'Joe Mauer 2012': ['Twins',
#   '147',
#   '545',
#   '641',
#   '174',
#   '129',
#   '31',
#   '4',
#   '10',
#   '81',
#   '85',
#   '90',
#   '10',
#   '88',
#   '2',
#   '3',
#   '1',
#   '23',
#   '8',
#   '4',
#   '.319',
#   ['Twins',
#    '641',
#    '14.0',
#    '13.7',
#    '1.02',
#    '.319',
#    '.416',
#    '.446',
#    '.861',
#    '.127',
#    '4.1',
#    '.364',
#    '1.2',
#    '-1.9',
#    '-0.9',
#    '104',
#    '31.2',
#    '.376',
#    '138'],
#   ['Twins',
#    '.364',
#    '2.35',
#    '25.0',
#    '52.6',
#    '22.4',
#    '1.0',
#    '9.7',
#    '8',
#    '3.3',
#    '0',
#    '0.0',
#    '32.1',
#    '37.1',
#    '30.8',
#    '11.7',
#    '51.2',
#    '37.1'],
#   ['Twins',
#    '3.97',
#    '-9.62',
#    '13.59',
#    '46.75',
#    '4.79',
#    '1.01',
#    '1.50',
#    '3',
#    '2.75',
#    '1.17'],
#   ['Twins',
#    '62.7',
#    '92.0',
#    '10.7',
#    '83.2',
#    '7.0',
#    '87.4',
#    '8.8',
#    '77.2',
#    '8.8',
#    '83.5',
#    '2.1',
#    '84.2',
#    '',
#    '',
#    '',
#    '',
#    '1.4'],
#   ['Twins',
#    '24.7',
#    '-3.9',
#    '2.3',
#    '0.2',
#    '1.0',
#    '1.9',
#    '',
#    '',
#    '1.45',
#    '-1.34',
#    '1.20',
#    '0.09',
#    '0.43',
#    '3.44',
#    '',
#    ''],
#   ['Twins',
#    '22.3',
#    '52.5',
#    '35.3',
#    '81.9',
#    '91.2',
#    '87.8',
#    '42.9',
#    '53.2',
#    '4.2'],
#   ['Twins',
#    '28.8',
#    '-1.6',
#    '-4.3',
#    '-1.4',
#    '27.2',
#    '-5.7',
#    '2.2',
#    '18.9',
#    '42.7',
#    '4.5',
#    '$29.1']],
#  'Yadier Molina 2013': ['Cardinals',
#   '136',
#   '505',
#   '541',
#   '161',
#   '105',
#   '44',
#   '0',
#   '12',
#   '68',
#   '80',
#   '30',
#   '4',
#   '55',
#   '3',
#   '3',
#   '0',
#   '14',
#   '3',
#   '2',
#   '.319',
#   ['Cardinals',
#    '541',
#    '5.5',
#    '10.2',
#    '0.55',
#    '.319',
#    '.359',
#    '.477',
#    '.836',
#    '.158',
#    '2.5',
#    '.338',
#    '-1.6',
#    '-0.3',
#    '-0.6',
#    '80',
#    '20.5',
#    '.362',
#    '133'],
#   ['Cardinals',
#    '.338',
#    '1.24',
#    '24.3',
#    '41.9',
#    '33.8',
#    '8.5',
#    '7.8',
#    '7',
#    '3.7',
#    '0',
#    '0.0',
#    '35.1',
#    '34.2',
#    '30.7',
#    '12.4',
#    '53.2',
#    '34.4'],
#   ['Cardinals',
#    '2.91',
#    '-7.81',
#    '10.72',
#    '32.32',
#    '3.60',
#    '0.92',
#    '1.18',
#    '5',
#    '1.95',
#    '1.21'],
#   ['Cardinals',
#    '56.0',
#    '91.8',
#    '16.5',
#    '83.6',
#    '5.7',
#    '87.8',
#    '11.4',
#    '77.6',
#    '9.0',
#    '82.4',
#    '1.4',
#    '82.8',
#    '',
#    '',
#    '',
#    '',
#    '0.7'],
#   ['Cardinals',
#    '17.2',
#    '-1.5',
#    '2.7',
#    '-1.0',
#    '0.8',
#    '1.8',
#    '',
#    '',
#    '1.64',
#    '-0.48',
#    '2.48',
#    '-0.49',
#    '0.46',
#    '6.84',
#    '',
#    ''],
#   ['Cardinals',
#    '35.5',
#    '75.1',
#    '53.5',
#    '80.9',
#    '90.8',
#    '87.2',
#    '45.5',
#    '64.0',
#    '6.8'],
#   ['Cardinals',
#    '20.1',
#    '-2.5',
#    '7.9',
#    '9.4',
#    '17.5',
#    '17.3',
#    '0.9',
#    '15.5',
#    '51.1',
#    '5.5',
#    '$40.9']],
#  'Jean Segura 2016': ['Diamondbacks',
#   '153',
#   '637',
#   '694',
#   '203',
#   '135',
#   '41',
#   '7',
#   '20',
#   '102',
#   '64',
#   '39',
#   '1',
#   '101',
#   '12',
#   '2',
#   '4',
#   '6',
#   '33',
#   '10',
#   '.319',
#   ['Diamondbacks',
#    '694',
#    '5.6',
#    '14.6',
#    '0.39',
#    '.319',
#    '.368',
#    '.499',
#    '.867',
#    '.181',
#    '6.8',
#    '.353',
#    '2.3',
#    '0.6',
#    '2.1',
#    '112',
#    '30.4',
#    '.371',
#    '126'],
#   ['Diamondbacks',
#    '.353',
#    '1.91',
#    '19.1',
#    '53.1',
#    '27.8',
#    '5.4',
#    '13.5',
#    '27',
#    '9.5',
#    '3',
#    '33.3',
#    '31.4',
#    '36.4',
#    '32.3',
#    '16.2',
#    '54.1',
#    '29.7'],
#   ['Diamondbacks',
#    '1.83',
#    '-12.29',
#    '14.12',
#    '27.47',
#    '2.64',
#    '1.01',
#    '1.01',
#    '2',
#    '2.25',
#    '-0.45'],
#   ['Diamondbacks',
#    '59.0',
#    '91.8',
#    '18.7',
#    '84.0',
#    '6.4',
#    '87.1',
#    '8.1',
#    '77.8',
#    '7.2',
#    '83.0',
#    '0.6',
#    '86.9',
#    '',
#    '',
#    '',
#    '',
#    '0.2'],
#   ['Diamondbacks',
#    '21.2',
#    '10.9',
#    '-1.5',
#    '4.3',
#    '5.2',
#    '0.8',
#    '',
#    '',
#    '1.33',
#    '2.17',
#    '-0.89',
#    '1.97',
#    '2.69',
#    '4.94',
#    '',
#    ''],
#   ['Diamondbacks',
#    '31.1',
#    '64.0',
#    '46.5',
#    '71.2',
#    '92.3',
#    '84.8',
#    '46.9',
#    '59.7',
#    '7.0'],
#   ['Diamondbacks',
#    '22.4',
#    '5.0',
#    '-2.5',
#    '2.8',
#    '27.4',
#    '0.3',
#    '1.2',
#    '20.9',
#    '49.9',
#    '5.1',
#    '$40.8']],
#  'Mookie Betts 2016': ['Red',
#   'Sox',
#   '158',
#   '672',
#   '730',
#   '214',
#   '136',
#   '42',
#   '5',
#   '31',
#   '122',
#   '113',
#   '49',
#   '1',
#   '80',
#   '2',
#   '7',
#   '0',
#   '12',
#   '26',
#   '4',
#   '.318',
#   ['Red',
#    'Sox',
#    '730',
#    '6.7',
#    '11.0',
#    '0.61',
#    '.318',
#    '.363',
#    '.534',
#    '.897',
#    '.216',
#    '6.4',
#    '.322',
#    '6.7',
#    '0.8',
#    '3.1',
#    '123',
#    '36.9',
#    '.379',
#    '137'],
#   ['Red',
#    'Sox',
#    '.322',
#    '1.05',
#    '19.3',
#    '41.4',
#    '39.4',
#    '12.3',
#    '13.2',
#    '18',
#    '7.3',
#    '1',
#    '50.0',
#    '39.7',
#    '35.1',
#    '25.2',
#    '17.4',
#    '49.3',
#    '33.4'],
#   ['Red',
#    'Sox',
#    '3.07',
#    '-12.09',
#    '15.16',
#    '37.04',
#    '3.62',
#    '0.98',
#    '0.07',
#    '1',
#    '3.28',
#    '-0.15'],
#   ['Red',
#    'Sox',
#    '53.7',
#    '92.3',
#    '17.8',
#    '84.0',
#    '6.4',
#    '87.8',
#    '9.6',
#    '77.8',
#    '9.2',
#    '83.0',
#    '1.4',
#    '84.3',
#    '2.0',
#    '74.7',
#    '0.1'],
#   ['Red',
#    'Sox',
#    '22.4',
#    '5.1',
#    '-4.6',
#    '2.6',
#    '10.4',
#    '0.2',
#    '1.3',
#    '1.54',
#    '1.06',
#    '-2.69',
#    '0.99',
#    '4.21',
#    '0.58',
#    '2.39'],
#   ['Red',
#    'Sox',
#    '25.5',
#    '58.4',
#    '41.2',
#    '71.6',
#    '94.8',
#    '87.3',
#    '47.6',
#    '60.8',
#    '5.2'],
#   ['Red',
#    'Sox',
#    '32.1',
#    '10.6',
#    '21.1',
#    '-7.1',
#    '42.7',
#    '14.0',
#    '2.6',
#    '22.0',
#    '81.4',
#    '8.3',
#    '$66.6']],
#  'Nelson Cruz 2010': ['Rangers',
#   '108',
#   '399',
#   '445',
#   '127',
#   '71',
#   '31',
#   '3',
#   '22',
#   '60',
#   '78',
#   '38',
#   '5',
#   '81',
#   '1',
#   '6',
#   '1',
#   '12',
#   '17',
#   '4',
#   '.318',
#   ['Rangers',
#    '445',
#    '8.5',
#    '18.2',
#    '0.47',
#    '.318',
#    '.374',
#    '.576',
#    '.950',
#    '.258',
#    '5.5',
#    '.348',
#    '0.8',
#    '-0.1',
#    '1.5',
#    '81',
#    '29.4',
#    '.404',
#    '147'],
#   ['Rangers',
#    '.348',
#    '0.83',
#    '18.0',
#    '37.2',
#    '44.9',
#    '6.2',
#    '15.2',
#    '16',
#    '13.3',
#    '0',
#    '0.0',
#    '36.3',
#    '34.2',
#    '29.5',
#    '16.0',
#    '46.2',
#    '37.9'],
#   ['Rangers',
#    '3.57',
#    '-8.47',
#    '12.04',
#    '28.84',
#    '2.71',
#    '1.13',
#    '3.11',
#    '5',
#    '2.99',
#    '0.17'],
#   ['Rangers',
#    '54.6',
#    '91.1',
#    '17.0',
#    '82.3',
#    '5.9',
#    '88.1',
#    '8.6',
#    '77.6',
#    '11.4',
#    '80.8',
#    '1.4',
#    '84.0',
#    '1.1',
#    '69.1',
#    '2.3'],
#   ['Rangers',
#    '17.5',
#    '8.9',
#    '-0.5',
#    '3.4',
#    '-4.4',
#    '-0.7',
#    '3.8',
#    '1.92',
#    '3.12',
#    '-0.53',
#    '2.36',
#    '-2.34',
#    '-2.88',
#    '21.15'],
#   ['Rangers',
#    '29.0',
#    '73.6',
#    '49.0',
#    '63.3',
#    '81.2',
#    '75.3',
#    '44.9',
#    '59.6',
#    '11.9'],
#   ['Rangers',
#    '24.5',
#    '2.2',
#    '10.1',
#    '-4.8',
#    '26.6',
#    '5.3',
#    '2.0',
#    '13.2',
#    '47.2',
#    '4.9',
#    '$29.4']],
#  'Jason Donald 2011': ['Indians',
#   '39',
#   '132',
#   '143',
#   '42',
#   '34',
#   '6',
#   '1',
#   '1',
#   '13',
#   '8',
#   '7',
#   '0',
#   '35',
#   '3',
#   '1',
#   '0',
#   '2',
#   '3',
#   '2',
#   '.318',
#   ['Indians',
#    '143',
#    '4.9',
#    '24.5',
#    '0.20',
#    '.318',
#    '.364',
#    '.402',
#    '.765',
#    '.083',
#    '4.2',
#    '.423',
#    '0.1',
#    '0.1',
#    '-0.3',
#    '19',
#    '2.7',
#    '.340',
#    '116'],
#   ['Indians',
#    '.423',
#    '2.43',
#    '26.5',
#    '52.0',
#    '21.4',
#    '9.5',
#    '4.8',
#    '5',
#    '9.8',
#    '0',
#    '0.0',
#    '29.6',
#    '36.7',
#    '33.7',
#    '28.6',
#    '43.9',
#    '27.6'],
#   ['Indians',
#    '-0.34',
#    '-2.62',
#    '2.28',
#    '-1.92',
#    '-0.17',
#    '1.05',
#    '0.60',
#    '3',
#    '-0.07',
#    '-0.25'],
#   ['Indians',
#    '59.3',
#    '91.4',
#    '17.7',
#    '82.7',
#    '5.5',
#    '85.2',
#    '9.5',
#    '76.7',
#    '7.4',
#    '80.0',
#    '0.6',
#    '86.0',
#    '',
#    '',
#    '',
#    '',
#    '',
#    ''],
#   ['Indians',
#    '1.2',
#    '0.9',
#    '0.2',
#    '-1.5',
#    '3.2',
#    '-0.3',
#    '',
#    '',
#    '0.39',
#    '0.98',
#    '0.56',
#    '-3.02',
#    '8.45',
#    '-10.12',
#    '',
#    ''],
#   ['Indians',
#    '32.1',
#    '64.3',
#    '47.9',
#    '59.5',
#    '90.7',
#    '80.1',
#    '49.0',
#    '69.2',
#    '9.5'],
#   ['Indians',
#    '2.7',
#    '-0.1',
#    '-3.3',
#    '0.9',
#    '2.6',
#    '-2.4',
#    '0.5',
#    '4.2',
#    '4.8',
#    '0.5',
#    '$3.9']],
#  'Jose Ramirez 2017': ['Indians',
#   '152',
#   '585',
#   '645',
#   '186',
#   '95',
#   '56',
#   '6',
#   '29',
#   '107',
#   '83',
#   '52',
#   '5',
#   '69',
#   '3',
#   '5',
#   '0',
#   '13',
#   '17',
#   '5',
#   '.318',
#   ['Indians',
#    '645',
#    '8.1',
#    '10.7',
#    '0.75',
#    '.318',
#    '.374',
#    '.583',
#    '.957',
#    '.265',
#    '6.0',
#    '.319',
#    '-1.4',
#    '0.5',
#    '0.9',
#    '120',
#    '41.1',
#    '.396',
#    '148'],
#   ['Indians',
#    '.319',
#    '0.98',
#    '21.4',
#    '38.9',
#    '39.7',
#    '9.7',
#    '14.1',
#    '11',
#    '5.4',
#    '0',
#    '0.0',
#    '46.3',
#    '32.1',
#    '21.7',
#    '16.7',
#    '49.3',
#    '34.0'],
#   ['Indians',
#    '1.07',
#    '-11.08',
#    '12.15',
#    '31.70',
#    '3.10',
#    '0.94',
#    '0.07',
#    '1',
#    '3.71',
#    '-2.57'],
#   ['Indians',
#    '54.5',
#    '92.3',
#    '13.0',
#    '85.0',
#    '4.3',
#    '88.4',
#    '11.5',
#    '78.2',
#    '15.2',
#    '83.9',
#    '1.5',
#    '83.1',
#    '',
#    '',
#    '',
#    '',
#    '0.7'],
#   ['Indians',
#    '28.9',
#    '-3.6',
#    '-1.4',
#    '3.1',
#    '12.0',
#    '1.5',
#    '',
#    '',
#    '2.06',
#    '-1.07',
#    '-1.22',
#    '1.05',
#    '3.07',
#    '3.96',
#    '',
#    ''],
#   ['Indians',
#    '25.4',
#    '66.6',
#    '43.4',
#    '76.6',
#    '92.7',
#    '87.4',
#    '43.7',
#    '55.8',
#    '5.5'],
#   ['Indians',
#    '38.4',
#    '0.0',
#    '4.4',
#    '2.3',
#    '38.4',
#    '6.6',
#    '2.3',
#    '19.9',
#    '67.2',
#    '6.7',
#    '$53.5']],
#  'Matt Carpenter 2013': ['Cardinals',
#   '157',
#   '626',
#   '717',
#   '199',
#   '126',
#   '55',
#   '7',
#   '11',
#   '126',
#   '78',
#   '72',
#   '1',
#   '98',
#   '9',
#   '7',
#   '3',
#   '4',
#   '3',
#   '3',
#   '.318',
#   ['Cardinals',
#    '717',
#    '10.0',
#    '13.7',
#    '0.73',
#    '.318',
#    '.392',
#    '.481',
#    '.873',
#    '.163',
#    '4.8',
#    '.359',
#    '4.5',
#    '1.3',
#    '-1.3',
#    '116',
#    '37.8',
#    '.381',
#    '146'],
#   ['Cardinals',
#    '.359',
#    '1.14',
#    '27.3',
#    '38.7',
#    '34.0',
#    '0.6',
#    '6.1',
#    '16',
#    '7.8',
#    '2',
#    '33.3',
#    '36.6',
#    '37.4',
#    '26.0',
#    '10.2',
#    '56.7',
#    '33.1'],
#   ['Cardinals',
#    '4.43',
#    '-9.18',
#    '13.61',
#    '52.11',
#    '5.78',
#    '0.88',
#    '0.94',
#    '3',
#    '4.36',
#    '0.68'],
#   ['Cardinals',
#    '62.6',
#    '91.6',
#    '11.6',
#    '82.9',
#    '5.3',
#    '88.0',
#    '11.4',
#    '77.1',
#    '7.6',
#    '83.0',
#    '1.5',
#    '82.7',
#    '',
#    '',
#    '',
#    '',
#    '0.2'],
#   ['Cardinals',
#    '23.8',
#    '7.0',
#    '-1.1',
#    '7.8',
#    '5.5',
#    '1.1',
#    '',
#    '',
#    '1.29',
#    '2.03',
#    '-0.71',
#    '2.33',
#    '2.47',
#    '2.51',
#    '',
#    ''],
#   ['Cardinals',
#    '21.8',
#    '55.6',
#    '37.1',
#    '75.9',
#    '95.0',
#    '88.8',
#    '45.3',
#    '61.0',
#    '4.1'],
#   ['Cardinals',
#    '37.2',
#    '4.5',
#    '1.0',
#    '2.2',
#    '41.7',
#    '3.2',
#    '1.1',
#    '20.5',
#    '66.5',
#    '7.2',
#    '$53.2']],
#  'Austin Jackson 2017': ['Indians',
#   '85',
#   '280',
#   '318',
#   '89',
#   '60',
#   '19',
#   '3',
#   '7',
#   '46',
#   '35',
#   '33',
#   '0',
#   '64',
#   '1',
#   '4',
#   '0',
#   '13',
#   '3',
#   '1',
#   '.318',
#   ['Indians',
#    '318',
#    '10.4',
#    '20.1',
#    '0.52',
#    '.318',
#    '.387',
#    '.482',
#    '.869',
#    '.164',
#    '5.0',
#    '.385',
#    '2.4',
#    '-1.9',
#    '-0.1',
#    '52',
#    '13.6',
#    '.371',
#    '131'],
#   ['Indians',
#    '.385',
#    '1.54',
#    '21.0',
#    '47.9',
#    '31.1',
#    '2.9',
#    '10.3',
#    '9',
#    '8.6',
#    '1',
#    '100.0',
#    '36.8',
#    '35.9',
#    '27.3',
#    '11.4',
#    '56.8',
#    '31.8'],
#   ['Indians',
#    '1.11',
#    '-5.15',
#    '6.26',
#    '11.17',
#    '1.12',
#    '0.94',
#    '1.67',
#    '5',
#    '1.10',
#    '0.08'],
#   ['Indians',
#    '59.6',
#    '92.4',
#    '16.3',
#    '85.0',
#    '4.3',
#    '87.7',
#    '8.6',
#    '77.3',
#    '10.6',
#    '83.2',
#    '0.6',
#    '83.6',
#    '',
#    '',
#    '',
#    '',
#    '',
#    ''],
#   ['Indians',
#    '8.4',
#    '2.0',
#    '-0.3',
#    '1.7',
#    '-1.0',
#    '0.3',
#    '',
#    '',
#    '1.03',
#    '0.89',
#    '-0.58',
#    '1.42',
#    '-0.69',
#    '4.26',
#    '',
#    ''],
#   ['Indians',
#    '23.8',
#    '63.6',
#    '42.2',
#    '62.3',
#    '87.8',
#    '80.0',
#    '46.2',
#    '58.8',
#    '8.4'],
#   ['Indians',
#    '12.2',
#    '0.4',
#    '-3.1',
#    '-1.4',
#    '12.6',
#    '-4.5',
#    '1.1',
#    '9.8',
#    '19.1',
#    '1.9',
#    '$15.2']],
#  'Adrian Beltre 2010': ['Red',
#   'Sox',
#   '154',
#   '589',
#   '641',
#   '189',
#   '110',
#   '49',
#   '2',
#   '28',
#   '84',
#   '102',
#   '40',
#   '10',
#   '82',
#   '5',
#   '7',
#   '0',
#   '25',
#   '2',
#   '1',
#   '.321',
#   ['Red',
#    'Sox',
#    '641',
#    '6.2',
#    '12.8',
#    '0.49',
#    '.321',
#    '.365',
#    '.553',
#    '.919',
#    '.233',
#    '2.9',
#    '.331',
#    '0.9',
#    '-3.9',
#    '-0.4',
#    '109',
#    '35.8',
#    '.391',
#    '140'],
#   ['Red',
#    'Sox',
#    '.331',
#    '1.00',
#    '19.1',
#    '40.5',
#    '40.5',
#    '10.6',
#    '13.5',
#    '15',
#    '7.2',
#    '0',
#    '0.0',
#    '37.2',
#    '38.9',
#    '23.9',
#    '18.3',
#    '41.6',
#    '40.1'],
#   ['Red',
#    'Sox',
#    '-0.03',
#    '-12.34',
#    '12.31',
#    '16.56',
#    '1.68',
#    '1.03',
#    '',
#    '',
#    '0',
#    '2.05',
#    '-2.07'],
#   ['Red',
#    'Sox',
#    '56.7',
#    '92.1',
#    '17.6',
#    '83.9',
#    '8.0',
#    '87.8',
#    '7.4',
#    '77.3',
#    '8.9',
#    '81.9',
#    '1.3',
#    '86.4',
#    '0.2',
#    '78.8',
#    '2.5'],
#   ['Red',
#    'Sox',
#    '15.5',
#    '0.9',
#    '3.5',
#    '4.8',
#    '1.7',
#    '0.4',
#    '0.1',
#    '1.17',
#    '0.21',
#    '1.87',
#    '2.80',
#    '0.82',
#    '1.31',
#    '1.44'],
#   ['Red',
#    'Sox',
#    '38.6',
#    '69.5',
#    '52.2',
#    '73.0',
#    '89.7',
#    '82.8',
#    '44.0',
#    '57.3',
#    '8.8'],
#   ['Red',
#    'Sox',
#    '30.3',
#    '-3.4',
#    '10.4',
#    '2.3',
#    '26.9',
#    '12.7',
#    '2.9',
#    '19.0',
#    '61.5',
#    '6.4',
#    '$38.3']],
#  'Omar Infante 2010': ['Braves',
#   '134',
#   '471',
#   '506',
#   '151',
#   '125',
#   '15',
#   '3',
#   '8',
#   '65',
#   '47',
#   '29',
#   '1',
#   '62',
#   '0',
#   '2',
#   '4',
#   '14',
#   '7',
#   '6',
#   '.321',
#   ['Braves',
#    '506',
#    '5.7',
#    '12.3',
#    '0.47',
#    '.321',
#    '.359',
#    '.416',
#    '.775',
#    '.096',
#    '4.0',
#    '.355',
#    '0.4',
#    '-1.5',
#    '-1.5',
#    '67',
#    '9.0',
#    '.343',
#    '111'],
#   ['Braves',
#    '.355',
#    '1.37',
#    '18.6',
#    '47.0',
#    '34.4',
#    '5.0',
#    '5.8',
#    '21',
#    '11.1',
#    '4',
#    '36.4',
#    '37.6',
#    '36.6',
#    '25.8',
#    '14.2',
#    '60.2',
#    '25.5'],
#   ['Braves',
#    '0.43',
#    '-8.75',
#    '9.19',
#    '2.75',
#    '0.34',
#    '0.98',
#    '1.03',
#    '13',
#    '0.76',
#    '-0.32'],
#   ['Braves',
#    '58.0',
#    '90.8',
#    '16.6',
#    '83.6',
#    '3.6',
#    '86.3',
#    '9.6',
#    '75.4',
#    '9.2',
#    '81.1',
#    '1.1',
#    '83.5',
#    '2.0',
#    '74.4',
#    '0.7'],
#   ['Braves',
#    '3.4',
#    '2.7',
#    '0.2',
#    '-1.0',
#    '-1.5',
#    '1.8',
#    '2.9',
#    '0.32',
#    '0.90',
#    '0.31',
#    '-0.61',
#    '-0.91',
#    '9.48',
#    '8.37'],
#   ['Braves',
#    '27.4',
#    '56.6',
#    '41.9',
#    '72.4',
#    '94.2',
#    '87.1',
#    '49.7',
#    '61.7',
#    '5.4'],
#   ['Braves',
#    '6.7',
#    '-2.6',
#    '-1.6',
#    '1.4',
#    '4.1',
#    '-0.2',
#    '0.7',
#    '15.0',
#    '19.6',
#    '2.0',
#    '$12.2']],
#  'Buster Posey 2017': ['Giants',
#   '140',
#   '494',
#   '568',
#   '158',
#   '112',
#   '34',
#   '0',
#   '12',
#   '62',
#   '67',
#   '61',
#   '13',
#   '66',
#   '8',
#   '5',
#   '0',
#   '17',
#   '6',
#   '1',
#   '.320',
#   ['Giants',
#    '568',
#    '10.7',
#    '11.6',
#    '0.92',
#    '.320',
#    '.400',
#    '.462',
#    '.861',
#    '.142',
#    '2.8',
#    '.347',
#    '-1.1',
#    '-1.1',
#    '0.4',
#    '91',
#    '21.4',
#    '.366',
#    '128'],
#   ['Giants',
#    '.347',
#    '1.32',
#    '23.3',
#    '43.6',
#    '33.0',
#    '2.8',
#    '8.4',
#    '6',
#    '3.2',
#    '0',
#    '0.0',
#    '36.5',
#    '40.0',
#    '23.6',
#    '14.1',
#    '52.9',
#    '33.0'],
#   ['Giants',
#    '0.91',
#    '-10.44',
#    '11.36',
#    '12.60',
#    '1.45',
#    '1.12',
#    '3.13',
#    '7',
#    '2.09',
#    '-1.28'],
#   ['Giants',
#    '59.1',
#    '92.8',
#    '16.8',
#    '84.5',
#    '5.4',
#    '88.5',
#    '7.5',
#    '77.9',
#    '9.8',
#    '84.2',
#    '0.5',
#    '81.8',
#    '0.8',
#    '75.3',
#    '2.5'],
#   ['Giants',
#    '1.7',
#    '9.1',
#    '0.9',
#    '2.0',
#    '2.4',
#    '0.7',
#    '0.8',
#    '0.14',
#    '2.60',
#    '0.83',
#    '1.29',
#    '1.18',
#    '6.88',
#    '4.78'],
#   ['Giants',
#    '25.6',
#    '67.4',
#    '44.2',
#    '75.9',
#    '89.7',
#    '85.3',
#    '44.6',
#    '52.6',
#    '6.5'],
#   ['Giants',
#    '20.6',
#    '-1.8',
#    '2.1',
#    '4.1',
#    '18.8',
#    '6.2',
#    '0.8',
#    '17.6',
#    '43.4',
#    '4.3',
#    '$34.6']],
#  'Xander Bogaerts 2015': ['Red',
#   'Sox',
#   '156',
#   '613',
#   '654',
#   '196',
#   '151',
#   '35',
#   '3',
#   '7',
#   '84',
#   '81',
#   '32',
#   '1',
#   '101',
#   '3',
#   '3',
#   '3',
#   '16',
#   '10',
#   '2',
#   '.320',
#   ['Red',
#    'Sox',
#    '654',
#    '4.9',
#    '15.4',
#    '0.32',
#    '.320',
#    '.355',
#    '.421',
#    '.776',
#    '.101',
#    '4.8',
#    '.372',
#    '3.7',
#    '-0.7',
#    '0.9',
#    '87',
#    '12.9',
#    '.338',
#    '111'],
#   ['Red',
#    'Sox',
#    '.372',
#    '2.05',
#    '21.3',
#    '52.9',
#    '25.8',
#    '10.6',
#    '5.3',
#    '30',
#    '11.1',
#    '1',
#    '16.7',
#    '33.8',
#    '34.2',
#    '32.1',
#    '21.0',
#    '51.5',
#    '27.4'],
#   ['Red',
#    'Sox',
#    '1.79',
#    '-10.45',
#    '12.24',
#    '9.14',
#    '0.87',
#    '0.97',
#    '',
#    '',
#    '0',
#    '-0.20',
#    '2.05'],
#   ['Red',
#    'Sox',
#    '54.9',
#    '92.2',
#    '18.4',
#    '84.2',
#    '5.5',
#    '87.1',
#    '8.6',
#    '78.0',
#    '8.1',
#    '83.0',
#    '2.5',
#    '84.7',
#    '2.1',
#    '75.7',
#    '0.2'],
#   ['Red',
#    'Sox',
#    '3.0',
#    '3.1',
#    '1.0',
#    '1.1',
#    '0.0',
#    '2.6',
#    '0.5',
#    '0.22',
#    '0.67',
#    '0.71',
#    '0.52',
#    '0.00',
#    '4.08',
#    '0.92'],
#   ['Red',
#    'Sox',
#    '35.6',
#    '64.0',
#    '49.1',
#    '70.0',
#    '88.6',
#    '81.5',
#    '47.3',
#    '62.4',
#    '9.1'],
#   ['Red',
#    'Sox',
#    '8.1',
#    '3.9',
#    '2.9',
#    '7.0',
#    '12.0',
#    '9.9',
#    '2.1',
#    '19.1',
#    '43.1',
#    '4.6',
#    '$36.6']],
#  'Jonathan Lucroy 2012': ['Brewers',
#   '96',
#   '316',
#   '346',
#   '101',
#   '68',
#   '17',
#   '4',
#   '12',
#   '46',
#   '58',
#   '22',
#   '1',
#   '44',
#   '4',
#   '3',
#   '1',
#   '12',
#   '4',
#   '1',
#   '.320',
#   ['Brewers',
#    '346',
#    '6.4',
#    '12.7',
#    '0.50',
#    '.320',
#    '.368',
#    '.513',
#    '.881',
#    '.193',
#    '5.1',
#    '.338',
#    '0.8',
#    '-1.1',
#    '0.0',
#    '57',
#    '17.4',
#    '.378',
#    '135'],
#   ['Brewers',
#    '.338',
#    '1.11',
#    '21.1',
#    '41.5',
#    '37.5',
#    '6.8',
#    '11.7',
#    '8',
#    '7.0',
#    '0',
#    '0.0',
#    '36.6',
#    '40.2',
#    '23.2',
#    '10.9',
#    '54.4',
#    '34.8'],
#   ['Brewers',
#    '0.47',
#    '-6.18',
#    '6.65',
#    '25.70',
#    '2.69',
#    '1.00',
#    '1.42',
#    '13',
#    '1.67',
#    '-1.20'],
#   ['Brewers',
#    '58.7',
#    '91.3',
#    '15.1',
#    '83.3',
#    '6.8',
#    '87.3',
#    '10.7',
#    '77.0',
#    '7.8',
#    '82.3',
#    '0.9',
#    '84.6',
#    '',
#    '',
#    '',
#    '',
#    '0.3'],
#   ['Brewers',
#    '3.1',
#    '4.3',
#    '5.0',
#    '0.1',
#    '3.5',
#    '-0.8',
#    '',
#    '',
#    '0.41',
#    '2.16',
#    '5.60',
#    '0.04',
#    '3.35',
#    '-6.95',
#    '',
#    ''],
#   ['Brewers',
#    '32.7',
#    '61.5',
#    '46.1',
#    '77.8',
#    '93.6',
#    '87.6',
#    '46.6',
#    '55.2',
#    '5.7'],
#   ['Brewers',
#    '14.6',
#    '-0.3',
#    '1.9',
#    '6.1',
#    '14.3',
#    '8.1',
#    '0.5',
#    '10.2',
#    '33.1',
#    '3.5',
#    '$22.5']],
#  'Freddie Freeman 2013': ['Braves',
#   '147',
#   '551',
#   '629',
#   '176',
#   '124',
#   '27',
#   '2',
#   '23',
#   '89',
#   '109',
#   '66',
#   '10',
#   '121',
#   '7',
#   '5',
#   '0',
#   '11',
#   '1',
#   '0',
#   '.319',
#   ['Braves',
#    '629',
#    '10.5',
#    '19.2',
#    '0.55',
#    '.319',
#    '.396',
#    '.501',
#    '.897',
#    '.181',
#    '2.8',
#    '.371',
#    '1.1',
#    '0.9',
#    '-0.5',
#    '105',
#    '36.2',
#    '.387',
#    '150'],
#   ['Braves',
#    '.371',
#    '1.08',
#    '26.7',
#    '38.2',
#    '35.2',
#    '2.6',
#    '15.0',
#    '9',
#    '5.4',
#    '0',
#    '0.0',
#    '36.1',
#    '38.2',
#    '25.8',
#    '9.2',
#    '53.1',
#    '37.7'],
#   ['Braves',
#    '6.09',
#    '-9.02',
#    '15.11',
#    '64.45',
#    '7.22',
#    '1.01',
#    '',
#    '',
#    '0',
#    '4.54',
#    '1.49'],
#   ['Braves',
#    '48.3',
#    '92.0',
#    '14.8',
#    '82.7',
#    '7.6',
#    '87.4',
#    '12.0',
#    '77.2',
#    '14.4',
#    '83.8',
#    '2.5',
#    '83.3',
#    '0.4',
#    '72.6',
#    '1.5'],
#   ['Braves',
#    '26.7',
#    '-1.9',
#    '1.1',
#    '5.5',
#    '4.2',
#    '2.2',
#    '0.9',
#    '2.34',
#    '-0.55',
#    '0.61',
#    '1.95',
#    '1.23',
#    '3.78',
#    '10.50'],
#   ['Braves',
#    '34.3',
#    '85.7',
#    '54.7',
#    '69.6',
#    '82.4',
#    '77.5',
#    '39.6',
#    '57.9',
#    '12.1'],
#   ['Braves',
#    '35.4',
#    '1.5',
#    '1.5',
#    '-11.1',
#    '36.9',
#    '-9.5',
#    '1.0',
#    '18.0',
#    '46.4',
#    '5.0',
#    '$37.0']],
#  'Yasiel Puig 2013': ['Dodgers',
#   '104',
#   '382',
#   '432',
#   '122',
#   '80',
#   '21',
#   '2',
#   '19',
#   '66',
#   '42',
#   '36',
#   '6',
#   '97',
#   '11',
#   '3',
#   '0',
#   '6',
#   '11',
#   '8',
#   '.319',
#   ['Dodgers',
#    '432',
#    '8.3',
#    '22.5',
#    '0.37',
#    '.319',
#    '.391',
#    '.534',
#    '.925',
#    '.215',
#    '4.7',
#    '.383',
#    '-2.5',
#    '0.6',
#    '-1.3',
#    '76',
#    '28.5',
#    '.398',
#    '160'],
#   ['Dodgers',
#    '.383',
#    '1.63',
#    '19.1',
#    '50.2',
#    '30.7',
#    '10.3',
#    '21.8',
#    '17',
#    '12.0',
#    '4',
#    '80.0',
#    '43.1',
#    '32.3',
#    '24.7',
#    '13.9',
#    '48.6',
#    '37.5'],
#   ['Dodgers',
#    '1.65',
#    '-7.24',
#    '8.88',
#    '18.52',
#    '2.10',
#    '1.01',
#    '3.81',
#    '5',
#    '3.03',
#    '-1.39'],
#   ['Dodgers',
#    '54.4',
#    '92.2',
#    '19.7',
#    '83.1',
#    '6.2',
#    '87.7',
#    '8.9',
#    '78.0',
#    '9.8',
#    '82.2',
#    '1.1',
#    '83.6',
#    '',
#    '',
#    '',
#    '',
#    '1.4'],
#   ['Dodgers',
#    '14.2',
#    '10.9',
#    '1.1',
#    '0.0',
#    '3.3',
#    '-1.0',
#    '',
#    '',
#    '1.72',
#    '3.62',
#    '1.20',
#    '-0.01',
#    '2.19',
#    '-6.14',
#    '',
#    ''],
#   ['Dodgers',
#    '37.6',
#    '79.6',
#    '53.3',
#    '52.9',
#    '79.3',
#    '67.6',
#    '37.3',
#    '59.3',
#    '17.0'],
#   ['Dodgers',
#    '29.2',
#    '-3.2',
#    '1.5',
#    '-3.9',
#    '26.0',
#    '-2.5',
#    '0.7',
#    '12.3',
#    '36.6',
#    '4.0',
#    '$29.2']],
#  'Bryce Harper 2017': ['Nationals',
#   '111',
#   '420',
#   '492',
#   '134',
#   '77',
#   '27',
#   '1',
#   '29',
#   '95',
#   '87',
#   '68',
#   '11',
#   '99',
#   '1',
#   '3',
#   '0',
#   '15',
#   '4',
#   '2',
#   '.319',
#   ['Nationals',
#    '492',
#    '13.8',
#    '20.1',
#    '0.69',
#    '.319',
#    '.413',
#    '.595',
#    '1.008',
#    '.276',
#    '3.7',
#    '.356',
#    '-0.1',
#    '-0.3',
#    '-0.4',
#    '99',
#    '39.4',
#    '.416',
#    '156'],
#   ['Nationals',
#    '.356',
#    '1.07',
#    '22.0',
#    '40.4',
#    '37.6',
#    '6.6',
#    '24.0',
#    '13',
#    '10.0',
#    '2',
#    '100.0',
#    '35.5',
#    '35.2',
#    '29.3',
#    '13.3',
#    '52.5',
#    '34.3'],
#   ['Nationals',
#    '4.00',
#    '-7.44',
#    '11.43',
#    '39.36',
#    '3.84',
#    '0.94',
#    '0.37',
#    '2',
#    '4.18',
#    '0.05'],
#   ['Nationals',
#    '54.6',
#    '93.7',
#    '10.6',
#    '85.1',
#    '5.6',
#    '88.5',
#    '11.5',
#    '78.7',
#    '13.4',
#    '85.6',
#    '2.3',
#    '84.5',
#    '2.0',
#    '78.4',
#    '1.5'],
#   ['Nationals',
#    '26.7',
#    '5.1',
#    '-0.2',
#    '0.7',
#    '4.5',
#    '-0.7',
#    '-1.1',
#    '2.49',
#    '2.44',
#    '-0.19',
#    '0.31',
#    '1.71',
#    '-1.64',
#    '-2.80'],
#   ['Nationals',
#    '30.1',
#    '74.4',
#    '49.0',
#    '55.9',
#    '85.1',
#    '74.8',
#    '42.7',
#    '54.7',
#    '12.4'],
#   ['Nationals',
#    '35.7',
#    '-0.8',
#    '2.9',
#    '-4.8',
#    '34.9',
#    '-2.0',
#    '0.7',
#    '15.2',
#    '48.8',
#    '4.9',
#    '$38.9']],
#  'Justin Morneau 2014': ['Rockies',
#   '135',
#   '502',
#   '550',
#   '160',
#   '108',
#   '32',
#   '3',
#   '17',
#   '62',
#   '82',
#   '34',
#   '4',
#   '60',
#   '6',
#   '8',
#   '0',
#   '7',
#   '0',
#   '3',
#   '.319',
#   ['Rockies',
#    '550',
#    '6.2',
#    '10.9',
#    '0.57',
#    '.319',
#    '.364',
#    '.496',
#    '.860',
#    '.177',
#    '2.5',
#    '.330',
#    '-2.4',
#    '1.1',
#    '-1.7',
#    '86',
#    '26.5',
#    '.373',
#    '122'],
#   ['Rockies',
#    '.330',
#    '1.34',
#    '23.1',
#    '44.0',
#    '32.9',
#    '10.1',
#    '11.5',
#    '8',
#    '4.0',
#    '0',
#    '0.0',
#    '31.8',
#    '39.1',
#    '29.1',
#    '15.3',
#    '53.1',
#    '31.6'],
#   ['Rockies',
#    '3.48',
#    '-8.98',
#    '12.46',
#    '24.80',
#    '2.67',
#    '1.03',
#    '3.37',
#    '5',
#    '1.48',
#    '1.88'],
#   ['Rockies',
#    '55.4',
#    '91.6',
#    '10.5',
#    '83.3',
#    '6.7',
#    '87.6',
#    '9.6',
#    '77.4',
#    '16.6',
#    '83.4',
#    '1.3',
#    '83.9',
#    '',
#    '',
#    '',
#    '',
#    '0.8'],
#   ['Rockies',
#    '11.2',
#    '7.0',
#    '2.6',
#    '4.1',
#    '6.0',
#    '-1.0',
#    '',
#    '',
#    '1.06',
#    '3.51',
#    '2.02',
#    '2.26',
#    '1.89',
#    '-3.95',
#    '',
#    ''],
#   ['Rockies',
#    '38.8',
#    '79.3',
#    '54.9',
#    '76.2',
#    '91.3',
#    '84.9',
#    '39.8',
#    '61.5',
#    '8.2'],
#   ['Rockies',
#    '13.5',
#    '-3.0',
#    '3.7',
#    '-9.6',
#    '10.5',
#    '-5.9',
#    '1.1',
#    '15.5',
#    '21.2',
#    '2.3',
#    '$17.7']],
#  'Danny Santana 2014': ['Twins',
#   '101',
#   '405',
#   '430',
#   '129',
#   '88',
#   '27',
#   '7',
#   '7',
#   '70',
#   '40',
#   '19',
#   '0',
#   '98',
#   '3',
#   '1',
#   '2',
#   '3',
#   '20',
#   '4',
#   '.319',
#   ['Twins',
#    '430',
#    '4.4',
#    '22.8',
#    '0.19',
#    '.319',
#    '.353',
#    '.472',
#    '.824',
#    '.153',
#    '8.2',
#    '.405',
#    '2.7',
#    '0.7',
#    '2.1',
#    '63',
#    '17.0',
#    '.362',
#    '132'],
#   ['Twins',
#    '.405',
#    '1.63',
#    '26.0',
#    '45.9',
#    '28.1',
#    '9.8',
#    '8.5',
#    '17',
#    '12.7',
#    '9',
#    '50.0',
#    '41.3',
#    '34.2',
#    '24.5',
#    '23.6',
#    '50.0',
#    '26.5'],
#   ['Twins',
#    '0.44',
#    '-7.89',
#    '8.33',
#    '15.33',
#    '1.66',
#    '1.10',
#    '2.20',
#    '3',
#    '1.07',
#    '-0.67'],
#   ['Twins',
#    '59.3',
#    '91.6',
#    '8.5',
#    '84.2',
#    '6.0',
#    '87.6',
#    '10.4',
#    '77.7',
#    '13.4',
#    '83.1',
#    '1.8',
#    '84.5',
#    '0.6',
#    '76.8',
#    '0.3'],
#   ['Twins',
#    '8.3',
#    '-1.8',
#    '2.9',
#    '3.4',
#    '5.5',
#    '1.6',
#    '-0.1',
#    '0.85',
#    '-1.28',
#    '2.92',
#    '2.02',
#    '2.50',
#    '5.37',
#    '-1.60'],
#   ['Twins',
#    '39.4',
#    '63.1',
#    '50.4',
#    '65.9',
#    '87.3',
#    '78.3',
#    '46.3',
#    '66.7',
#    '10.9'],
#   ['Twins',
#    '15.1',
#    '5.5',
#    '-0.5',
#    '1.9',
#    '20.6',
#    '1.5',
#    '1.4',
#    '12.1',
#    '35.6',
#    '3.9',
#    '$29.7']],
#  'Eric Hosmer 2017': ['Royals',
#   '162',
#   '603',
#   '671',
#   '192',
#   '135',
#   '31',
#   '1',
#   '25',
#   '98',
#   '94',
#   '66',
#   '3',
#   '104',
#   '0',
#   '2',
#   '0',
#   '20',
#   '6',
#   '1',
#   '.318',
#   ['Royals',
#    '671',
#    '9.8',
#    '15.5',
#    '0.63',
#    '.318',
#    '.385',
#    '.498',
#    '.882',
#    '.179',
#    '3.4',
#    '.351',
#    '2.2',
#    '-0.6',
#    '0.3',
#    '113',
#    '31.3',
#    '.376',
#    '135'],
#   ['Royals',
#    '.351',
#    '2.50',
#    '22.2',
#    '55.6',
#    '22.2',
#    '7.2',
#    '22.5',
#    '19',
#    '6.8',
#    '1',
#    '100.0',
#    '31.3',
#    '35.7',
#    '32.9',
#    '21.8',
#    '48.7',
#    '29.5'],
#   ['Royals',
#    '2.06',
#    '-11.50',
#    '13.56',
#    '34.55',
#    '3.45',
#    '0.98',
#    '1.62',
#    '1',
#    '2.92',
#    '-0.83'],
#   ['Royals',
#    '52.6',
#    '92.6',
#    '16.5',
#    '84.4',
#    '6.8',
#    '88.1',
#    '12.2',
#    '78.5',
#    '10.2',
#    '84.4',
#    '1.6',
#    '83.1',
#    '',
#    '',
#    '',
#    '',
#    '0.5'],
#   ['Royals',
#    '21.8',
#    '0.5',
#    '-2.2',
#    '5.5',
#    '4.1',
#    '1.3',
#    '',
#    '',
#    '1.61',
#    '0.13',
#    '-1.25',
#    '1.74',
#    '1.55',
#    '3.28',
#    '',
#    ''],
#   ['Royals',
#    '30.0',
#    '69.2',
#    '47.0',
#    '64.2',
#    '89.2',
#    '80.2',
#    '43.5',
#    '58.1',
#    '9.3'],
#   ['Royals',
#    '29.0',
#    '1.9',
#    '-0.8',
#    '-12.0',
#    '30.9',
#    '-12.8',
#    '2.4',
#    '20.7',
#    '41.2',
#    '4.1',
#    '$32.8']],
#  'David DeJesus 2010': ['Royals',
#   '91',
#   '352',
#   '394',
#   '112',
#   '81',
#   '23',
#   '3',
#   '5',
#   '46',
#   '37',
#   '34',
#   '2',
#   '47',
#   '4',
#   '1',
#   '3',
#   '10',
#   '3',
#   '3',
#   '.318',
#   ['Royals',
#    '394',
#    '8.6',
#    '11.9',
#    '0.72',
#    '.318',
#    '.384',
#    '.443',
#    '.827',
#    '.125',
#    '3.6',
#    '.355',
#    '0.2',
#    '-0.4',
#    '-1.0',
#    '59',
#    '14.1',
#    '.366',
#    '127'],
#   ['Royals',
#    '.355',
#    '1.45',
#    '20.9',
#    '46.8',
#    '32.2',
#    '6.2',
#    '5.2',
#    '9',
#    '6.4',
#    '1',
#    '12.5',
#    '35.3',
#    '35.0',
#    '29.8',
#    '12.9',
#    '55.3',
#    '31.7'],
#   ['Royals',
#    '0.12',
#    '-6.79',
#    '6.91',
#    '5.10',
#    '0.51',
#    '1.02',
#    '1.15',
#    '1',
#    '0.97',
#    '-0.86'],
#   ['Royals',
#    '63.0',
#    '91.6',
#    '12.0',
#    '82.7',
#    '3.5',
#    '87.3',
#    '8.3',
#    '76.4',
#    '10.7',
#    '83.6',
#    '1.2',
#    '86.1',
#    '1.3',
#    '66.8',
#    '2.0'],
#   ['Royals',
#    '4.7',
#    '3.8',
#    '1.4',
#    '0.8',
#    '-1.3',
#    '-1.0',
#    '1.5',
#    '0.48',
#    '2.07',
#    '2.63',
#    '0.59',
#    '-0.80',
#    '-5.24',
#    '7.33'],
#   ['Royals',
#    '22.6',
#    '57.1',
#    '38.1',
#    '72.1',
#    '96.7',
#    '88.7',
#    '45.0',
#    '55.8',
#    '4.3'],
#   ['Royals',
#    '12.7',
#    '-1.2',
#    '2.0',
#    '-3.1',
#    '11.6',
#    '-1.1',
#    '1.8',
#    '11.7',
#    '23.9',
#    '2.5',
#    '$14.9']],
#  'Jayson Werth 2013': ['Nationals',
#   '129',
#   '462',
#   '532',
#   '147',
#   '98',
#   '24',
#   '0',
#   '25',
#   '84',
#   '82',
#   '60',
#   '3',
#   '101',
#   '5',
#   '5',
#   '0',
#   '9',
#   '10',
#   '1',
#   '.318',
#   ['Nationals',
#    '532',
#    '11.3',
#    '19.0',
#    '0.59',
#    '.318',
#    '.398',
#    '.532',
#    '.931',
#    '.214',
#    '4.0',
#    '.358',
#    '-0.6',
#    '0.8',
#    '1.1',
#    '95',
#    '37.0',
#    '.403',
#    '159'],
#   ['Nationals',
#    '.358',
#    '0.95',
#    '26.0',
#    '36.1',
#    '38.0',
#    '10.1',
#    '18.0',
#    '5',
#    '3.8',
#    '0',
#    '0.0',
#    '40.2',
#    '35.3',
#    '24.6',
#    '14.2',
#    '45.9',
#    '39.9'],
#   ['Nationals',
#    '2.65',
#    '-8.75',
#    '11.39',
#    '36.40',
#    '4.04',
#    '1.01',
#    '1.94',
#    '1',
#    '3.68',
#    '-1.07'],
#   ['Nationals',
#    '60.3',
#    '92.1',
#    '16.8',
#    '83.9',
#    '6.0',
#    '87.5',
#    '8.6',
#    '77.8',
#    '7.3',
#    '82.7',
#    '1.1',
#    '83.1',
#    '',
#    '',
#    '',
#    '',
#    '0.6'],
#   ['Nationals',
#    '31.7',
#    '-1.0',
#    '2.7',
#    '1.0',
#    '2.9',
#    '-1.6',
#    '',
#    '',
#    '2.34',
#    '-0.25',
#    '2.03',
#    '0.52',
#    '1.78',
#    '-6.61',
#    '',
#    ''],
#   ['Nationals',
#    '24.3',
#    '58.5',
#    '40.5',
#    '70.3',
#    '87.3',
#    '82.0',
#    '47.5',
#    '60.5',
#    '7.3'],
#   ['Nationals',
#    '35.2',
#    '1.3',
#    '-6.0',
#    '-5.7',
#    '36.5',
#    '-11.8',
#    '0.8',
#    '15.2',
#    '40.7',
#    '4.4',
#    '$32.5']],
#  'David Ortiz 2012': ['Red',
#   'Sox',
#   '90',
#   '324',
#   '383',
#   '103',
#   '54',
#   '26',
#   '0',
#   '23',
#   '65',
#   '60',
#   '56',
#   '13',
#   '51',
#   '0',
#   '3',
#   '0',
#   '6',
#   '0',
#   '1',
#   '.318',
#   ['Red',
#    'Sox',
#    '383',
#    '14.6',
#    '13.3',
#    '1.10',
#    '.318',
#    '.415',
#    '.611',
#    '1.026',
#    '.293',
#    '1.6',
#    '.316',
#    '-5.1',
#    '0.9',
#    '-0.8',
#    '78',
#    '34.0',
#    '.425',
#    '170'],
#   ['Red',
#    'Sox',
#    '.316',
#    '0.88',
#    '21.5',
#    '36.7',
#    '41.8',
#    '7.8',
#    '20.0',
#    '1',
#    '1.0',
#    '1',
#    '100.0',
#    '39.9',
#    '31.2',
#    '29.0',
#    '12.3',
#    '48.9',
#    '38.8'],
#   ['Red',
#    'Sox',
#    '2.47',
#    '-5.23',
#    '7.70',
#    '30.75',
#    '3.07',
#    '0.93',
#    '1.11',
#    '2',
#    '2.78',
#    '-0.13'],
#   ['Red',
#    'Sox',
#    '53.4',
#    '91.9',
#    '14.6',
#    '82.6',
#    '6.2',
#    '88.0',
#    '10.7',
#    '77.6',
#    '12.9',
#    '84.1',
#    '2.2',
#    '83.8',
#    '',
#    '',
#    '',
#    '',
#    '3.1'],
#   ['Red',
#    'Sox',
#    '22.8',
#    '-0.2',
#    '2.5',
#    '2.8',
#    '3.1',
#    '1.6',
#    '',
#    '',
#    '2.95',
#    '-0.11',
#    '2.83',
#    '1.79',
#    '1.63',
#    '4.88',
#    '',
#    ''],
#   ['Red',
#    'Sox',
#    '26.8',
#    '67.0',
#    '42.8',
#    '77.4',
#    '89.2',
#    '84.7',
#    '39.9',
#    '54.6',
#    '6.3'],
#   ['Red',
#    'Sox',
#    '31.1',
#    '-5.0',
#    '-0.1',
#    '-9.2',
#    '26.1',
#    '-9.3',
#    '1.3',
#    '11.3',
#    '29.4',
#    '3.1',
#    '$20.1']],
#  'Omar Infante 2013': ['Tigers',
#   '118',
#   '453',
#   '476',
#   '144',
#   '107',
#   '24',
#   '3',
#   '10',
#   '54',
#   '51',
#   '20',
#   '1',
#   '44',
#   '0',
#   '3',
#   '0',
#   '11',
#   '5',
#   '2',
#   '.318',
#   ['Tigers',
#    '476',
#    '4.2',
#    '9.2',
#    '0.45',
#    '.318',
#    '.345',
#    '.450',
#    '.795',
#    '.132',
#    '3.9',
#    '.333',
#    '-0.7',
#    '0.5',
#    '-0.2',
#    '64',
#    '12.1',
#    '.346',
#    '118'],
#   ['Tigers',
#    '.333',
#    '1.01',
#    '23.6',
#    '38.4',
#    '37.9',
#    '9.7',
#    '6.5',
#    '9',
#    '5.8',
#    '4',
#    '66.7',
#    '46.6',
#    '36.9',
#    '16.5',
#    '13.6',
#    '59.5',
#    '26.9'],
#   ['Tigers',
#    '-0.45',
#    '-8.00',
#    '7.55',
#    '6.35',
#    '0.63',
#    '0.97',
#    '1.38',
#    '1',
#    '0.69',
#    '-1.16'],
#   ['Tigers',
#    '58.6',
#    '91.5',
#    '15.6',
#    '83.5',
#    '6.9',
#    '88.0',
#    '7.7',
#    '77.5',
#    '10.0',
#    '82.7',
#    '0.8',
#    '84.2',
#    '0.5',
#    '75.6',
#    '0.3'],
#   ['Tigers',
#    '-1.1',
#    '1.9',
#    '9.9',
#    '-3.9',
#    '1.0',
#    '-1.0',
#    '1.6',
#    '-0.12',
#    '0.78',
#    '9.21',
#    '-3.25',
#    '0.65',
#    '-8.23',
#    '19.94'],
#   ['Tigers',
#    '29.5',
#    '61.7',
#    '45.4',
#    '69.5',
#    '91.7',
#    '84.4',
#    '49.6',
#    '60.3',
#    '7.1'],
#   ['Tigers',
#    '9.5',
#    '-0.4',
#    '0.7',
#    '1.8',
#    '9.1',
#    '2.5',
#    '1.7',
#    '13.6',
#    '26.9',
#    '2.9',
#    '$21.5']],
#  'Jorge Alfaro 2017': ['Phillies',
#   '29',
#   '107',
#   '114',
#   '34',
#   '23',
#   '6',
#   '0',
#   '5',
#   '12',
#   '14',
#   '3',
#   '1',
#   '33',
#   '4',
#   '0',
#   '0',
#   '2',
#   '0',
#   '0',
#   '.318',
#   ['Phillies',
#    '114',
#    '2.6',
#    '28.9',
#    '0.09',
#    '.318',
#    '.360',
#    '.514',
#    '.874',
#    '.196',
#    '0.9',
#    '.420',
#    '-1.7',
#    '0.0',
#    '-0.1',
#    '19',
#    '4.7',
#    '.369',
#    '127'],
#   ['Phillies',
#    '.420',
#    '1.70',
#    '16.2',
#    '52.7',
#    '31.1',
#    '4.3',
#    '21.7',
#    '2',
#    '5.1',
#    '0',
#    '0.0',
#    '31.1',
#    '40.5',
#    '28.4',
#    '21.6',
#    '54.1',
#    '24.3'],
#   ['Phillies',
#    '0.32',
#    '-1.69',
#    '2.01',
#    '5.16',
#    '0.53',
#    '0.88',
#    '',
#    '',
#    '0',
#    '0.42',
#    '-0.05'],
#   ['Phillies',
#    '52.9',
#    '93.2',
#    '24.6',
#    '84.7',
#    '1.5',
#    '88.8',
#    '12.0',
#    '77.7',
#    '6.4',
#    '83.7',
#    '0.3',
#    '90.0',
#    '2.3',
#    '78.7',
#    '1.0'],
#   ['Phillies',
#    '0.7',
#    '-1.3',
#    '0.8',
#    '3.0',
#    '1.6',
#    '-0.2',
#    '0.3',
#    '0.34',
#    '-1.34',
#    '13.55',
#    '6.31',
#    '6.28',
#    '-17.43',
#    '3.13'],
#   ['Phillies',
#    '46.2',
#    '83.1',
#    '61.9',
#    '39.4',
#    '84.1',
#    '64.9',
#    '42.5',
#    '64.0',
#    '21.7'],
#   ['Phillies',
#    '3.9',
#    '-1.8',
#    '-1.4',
#    '2.0',
#    '2.2',
#    '0.6',
#    '0.2',
#    '3.5',
#    '6.4',
#    '0.6',
#    '$5.1']],
#  'Dustin Pedroia 2016': ['Red',
#   'Sox',
#   '154',
#   '633',
#   '698',
#   '201',
#   '149',
#   '36',
#   '1',
#   '15',
#   '105',
#   '74',
#   '61',
#   '0',
#   '73',
#   '0',
#   '3',
#   '1',
#   '24',
#   '7',
#   '4',
#   '.318',
#   ['Red',
#    'Sox',
#    '698',
#    '8.7',
#    '10.5',
#    '0.84',
#    '.318',
#    '.376',
#    '.449',
#    '.825',
#    '.131',
#    '3.5',
#    '.339',
#    '-0.9',
#    '-2.7',
#    '-0.7',
#    '105',
#    '23.0',
#    '.358',
#    '122'],
#   ['Red',
#    'Sox',
#    '.339',
#    '1.83',
#    '24.2',
#    '49.0',
#    '26.8',
#    '8.6',
#    '9.9',
#    '20',
#    '7.2',
#    '0',
#    '0.0',
#    '35.6',
#    '33.0',
#    '31.4',
#    '15.8',
#    '52.3',
#    '31.9'],
#   ['Red',
#    'Sox',
#    '2.95',
#    '-11.31',
#    '14.26',
#    '20.20',
#    '1.99',
#    '0.96',
#    '3.22',
#    '2',
#    '1.48',
#    '1.59'],
#   ['Red',
#    'Sox',
#    '58.7',
#    '92.3',
#    '16.5',
#    '84.2',
#    '5.9',
#    '87.5',
#    '8.3',
#    '78.1',
#    '8.0',
#    '83.5',
#    '1.2',
#    '84.5',
#    '1.4',
#    '75.8',
#    '0.0'],
#   ['Red',
#    'Sox',
#    '9.7',
#    '6.9',
#    '-1.1',
#    '-3.2',
#    '9.1',
#    '-0.5',
#    '-0.5',
#    '0.60',
#    '1.54',
#    '-0.69',
#    '-1.40',
#    '4.20',
#    '-1.43',
#    '-1.26'],
#   ['Red',
#    'Sox',
#    '26.0',
#    '60.9',
#    '43.1',
#    '80.3',
#    '92.5',
#    '88.8',
#    '49.2',
#    '58.0',
#    '4.8'],
#   ['Red',
#    'Sox',
#    '18.4',
#    '-4.3',
#    '8.9',
#    '2.2',
#    '14.1',
#    '11.1',
#    '2.5',
#    '21.1',
#    '48.7',
#    '5.0',
#    '$39.9']],
#  'Willie Bloomquist 2013': ['Diamondbacks',
#   '48',
#   '139',
#   '150',
#   '44',
#   '38',
#   '5',
#   '1',
#   '0',
#   '16',
#   '14',
#   '8',
#   '0',
#   '11',
#   '2',
#   '1',
#   '0',
#   '3',
#   '0',
#   '2',
#   '.317',
#   ['Diamondbacks',
#    '150',
#    '5.3',
#    '7.3',
#    '0.73',
#    '.317',
#    '.360',
#    '.367',
#    '.727',
#    '.050',
#    '3.0',
#    '.341',
#    '0.5',
#    '-0.6',
#    '-0.9',
#    '18',
#    '1.3',
#    '.325',
#    '101'],
#   ['Diamondbacks',
#    '.341',
#    '1.91',
#    '25.0',
#    '49.2',
#    '25.8',
#    '15.2',
#    '0.0',
#    '1',
#    '1.6',
#    '1',
#    '100.0',
#    '24.8',
#    '48.1',
#    '27.1',
#    '15.5',
#    '52.7',
#    '31.8'],
#   ['Diamondbacks',
#    '0.27',
#    '-2.78',
#    '3.05',
#    '2.86',
#    '0.31',
#    '1.13',
#    '1.38',
#    '18',
#    '-0.19',
#    '0.42'],
#   ['Diamondbacks',
#    '57.2',
#    '92.1',
#    '17.7',
#    '83.9',
#    '4.9',
#    '87.6',
#    '9.7',
#    '75.0',
#    '8.8',
#    '81.4',
#    '1.8',
#    '84.8',
#    '',
#    '',
#    '',
#    '',
#    '0.2'],
#   ['Diamondbacks',
#    '2.1',
#    '1.1',
#    '0.0',
#    '-1.0',
#    '-0.8',
#    '0.5',
#    '',
#    '',
#    '0.70',
#    '1.25',
#    '-0.16',
#    '-2.07',
#    '-1.89',
#    '5.99',
#    '',
#    ''],
#   ['Diamondbacks',
#    '32.4',
#    '68.6',
#    '49.2',
#    '69.7',
#    '93.3',
#    '85.0',
#    '46.5',
#    '62.0',
#    '7.4'],
#   ['Diamondbacks',
#    '0.1',
#    '-1.0',
#    '-1.3',
#    '0.3',
#    '-0.9',
#    '-0.9',
#    '0.2',
#    '4.3',
#    '2.7',
#    '0.3',
#    '$2.2']],
#  'Derek Jeter 2012': ['Yankees',
#   '159',
#   '683',
#   '740',
#   '216',
#   '169',
#   '32',
#   '0',
#   '15',
#   '99',
#   '58',
#   '45',
#   '1',
#   '90',
#   '5',
#   '1',
#   '6',
#   '24',
#   '9',
#   '4',
#   '.316',
#   ['Yankees',
#    '740',
#    '6.1',
#    '12.2',
#    '0.50',
#    '.316',
#    '.362',
#    '.429',
#    '.791',
#    '.113',
#    '3.3',
#    '.347',
#    '0.0',
#    '-2.7',
#    '-0.8',
#    '103',
#    '19.1',
#    '.347',
#    '117'],
#   ['Yankees',
#    '.347',
#    '3.94',
#    '21.7',
#    '62.5',
#    '15.9',
#    '3.2',
#    '16.1',
#    '30',
#    '8.2',
#    '5',
#    '35.7',
#    '28.5',
#    '39.3',
#    '32.2',
#    '12.8',
#    '64.5',
#    '22.7'],
#   ['Yankees',
#    '0.92',
#    '-12.25',
#    '13.17',
#    '13.43',
#    '1.33',
#    '1.00',
#    '',
#    '',
#    '0',
#    '1.15',
#    '-0.23'],
#   ['Yankees',
#    '64.9',
#    '92.1',
#    '11.3',
#    '83.9',
#    '7.4',
#    '88.5',
#    '6.0',
#    '78.1',
#    '8.6',
#    '83.8',
#    '1.4',
#    '84.6',
#    '0.4',
#    '76.4',
#    '0.2'],
#   ['Yankees',
#    '21.2',
#    '-5.8',
#    '2.8',
#    '3.6',
#    '-4.0',
#    '-0.3',
#    '-0.6',
#    '1.20',
#    '-1.87',
#    '1.38',
#    '2.16',
#    '-1.68',
#    '-0.69',
#    '-6.41'],
#   ['Yankees',
#    '30.7',
#    '73.2',
#    '49.6',
#    '73.3',
#    '90.4',
#    '84.5',
#    '44.5',
#    '60.5',
#    '7.7'],
#   ['Yankees',
#    '14.6',
#    '-3.5',
#    '-8.2',
#    '3.4',
#    '11.2',
#    '-4.8',
#    '2.5',
#    '21.9',
#    '30.8',
#    '3.2',
#    '$21.0']],
#  'Miguel Cabrera 2016': ['Tigers',
#   '158',
#   '595',
#   '679',
#   '188',
#   '118',
#   '31',
#   '1',
#   '38',
#   '92',
#   '108',
#   '75',
#   '15',
#   '116',
#   '4',
#   '5',
#   '0',
#   '26',
#   '0',
#   '0',
#   '.316',
#   ['Tigers',
#    '679',
#    '11.0',
#    '17.1',
#    '0.65',
#    '.316',
#    '.393',
#    '.563',
#    '.956',
#    '.247',
#    '1.3',
#    '.336',
#    '-6.2',
#    '-3.0',
#    '-0.4',
#    '125',
#    '45.1',
#    '.399',
#    '152'],
#   ['Tigers',
#    '.336',
#    '1.17',
#    '22.7',
#    '41.7',
#    '35.5',
#    '4.7',
#    '22.1',
#    '4',
#    '2.0',
#    '0',
#    '0.0',
#    '37.8',
#    '33.1',
#    '29.1',
#    '9.7',
#    '49.2',
#    '41.1'],
#   ['Tigers',
#    '3.12',
#    '-11.31',
#    '14.42',
#    '35.89',
#    '3.57',
#    '0.96',
#    '2.97',
#    '2',
#    '4.94',
#    '-1.69'],
#   ['Tigers',
#    '55.5',
#    '92.6',
#    '14.8',
#    '84.2',
#    '6.4',
#    '87.2',
#    '10.1',
#    '78.4',
#    '10.7',
#    '85.0',
#    '1.4',
#    '84.4',
#    '1.2',
#    '75.2',
#    '1.7'],
#   ['Tigers',
#    '19.8',
#    '8.7',
#    '-0.5',
#    '9.3',
#    '-2.3',
#    '0.0',
#    '1.7',
#    '1.45',
#    '2.39',
#    '-0.33',
#    '3.73',
#    '-0.87',
#    '-0.12',
#    '5.71'],
#   ['Tigers',
#    '32.9',
#    '72.9',
#    '49.5',
#    '68.3',
#    '85.9',
#    '79.1',
#    '41.7',
#    '58.5',
#    '10.2'],
#   ['Tigers',
#    '42.1',
#    '-9.6',
#    '1.9',
#    '-11.7',
#    '32.5',
#    '-9.8',
#    '2.4',
#    '20.5',
#    '45.5',
#    '4.7',
#    '$37.3']],
#  'Josh Harrison 2014': ['Pirates',
#   '143',
#   '520',
#   '550',
#   '164',
#   '106',
#   '38',
#   '7',
#   '13',
#   '77',
#   '52',
#   '22',
#   '1',
#   '81',
#   '4',
#   '2',
#   '2',
#   '6',
#   '18',
#   '7',
#   '.315',
#   ['Pirates',
#    '550',
#    '4.0',
#    '14.7',
#    '0.27',
#    '.315',
#    '.347',
#    '.490',
#    '.837',
#    '.175',
#    '6.6',
#    '.353',
#    '2.4',
#    '0.5',
#    '0.5',
#    '82',
#    '23.3',
#    '.365',
#    '137'],
#   ['Pirates',
#    '.353',
#    '0.96',
#    '24.0',
#    '37.3',
#    '38.7',
#    '7.1',
#    '7.7',
#    '17',
#    '10.4',
#    '2',
#    '33.3',
#    '45.4',
#    '30.9',
#    '23.7',
#    '14.9',
#    '53.3',
#    '31.8'],
#   ['Pirates',
#    '3.75',
#    '-8.25',
#    '11.99',
#    '24.39',
#    '2.81',
#    '0.97',
#    '1.49',
#    '21',
#    '2.64',
#    '1.23'],
#   ['Pirates',
#    '56.7',
#    '91.6',
#    '17.7',
#    '84.1',
#    '5.4',
#    '87.1',
#    '10.5',
#    '76.9',
#    '8.7',
#    '83.0',
#    '0.8',
#    '82.9',
#    '0.3',
#    '77.0',
#    '0.2'],
#   ['Pirates',
#    '22.3',
#    '1.0',
#    '1.9',
#    '-1.4',
#    '0.2',
#    '-0.3',
#    '-0.5',
#    '2.00',
#    '0.29',
#    '1.80',
#    '-0.70',
#    '0.09',
#    '-1.99',
#    '-9.10'],
#   ['Pirates',
#    '38.3',
#    '67.7',
#    '52.2',
#    '71.7',
#    '86.8',
#    '81.0',
#    '47.4',
#    '61.3',
#    '9.9'],
#   ['Pirates',
#    '22.8',
#    '3.4',
#    '1.6',
#    '-0.6',
#    '26.2',
#    '1.0',
#    '1.1',
#    '15.5',
#    '43.7',
#    '4.8',
#    '$36.4']],
#  'David Dahl 2016': ['Rockies',
#   '63',
#   '222',
#   '237',
#   '70',
#   '47',
#   '12',
#   '4',
#   '7',
#   '42',
#   '24',
#   '15',
#   '0',
#   '59',
#   '0',
#   '0',
#   '0',
#   '3',
#   '5',
#   '0',
#   '.315',
#   ['Rockies',
#    '237',
#    '6.3',
#    '24.9',
#    '0.25',
#    '.315',
#    '.359',
#    '.500',
#    '.859',
#    '.185',
#    '7.7',
#    '.404',
#    '1.1',
#    '0.8',
# ...
#    '40.4',
#    '61.3',
#    '10.1'],
#   ['Rangers',
#    '-6.1',
#    '-5.0',
#    '-0.7',
#    '7.3',
#    '-11.1',
#    '6.6',
#    '1.9',
#    '15.1',
#    '12.5',
#    '1.4',
#    '$10.0']],
#  'Jedd Gyorko 2017': ['Cardinals',
#   '125',
#   '426',
#   '481',
#   '116',
#   '73',
#   '21',
#   '2',
#   '20',
#   '52',
#   '67',
#   '47',
#   '1',
#   '105',
#   '1',
#   '7',
#   '0',
#   '12',
#   '6',
#   '2',
#   '.272',
#   ['Cardinals',
#    '481',
#    '9.8',
#    '21.8',
#    '0.45',
#    '.272',
#    '.341',
#    '.472',
#    '.813',
#    '.200',
#    '3.8',
#    '.312',
#    '-2.2',
#    '-0.3',
#    '0.0',
#    '68',
#    '9.4',
#    '.344',
#    '112'],
#   ['Cardinals',
#    '.312',
#    '1.03',
#    '20.1',
#    '40.5',
#    '39.3',
#    '8.5',
#    '15.5',
#    '7',
#    '5.3',
#    '0',
#    '0.0',
#    '43.0',
#    '30.5',
#    '26.5',
#    '19.2',
#    '50.0',
#    '30.8'],
#   ['Cardinals',
#    '-0.14',
#    '-8.72',
#    '8.57',
#    '9.63',
#    '1.01',
#    '1.00',
#    '2.07',
#    '12',
#    '0.47',
#    '-0.61'],
#   ['Cardinals',
#    '51.2',
#    '93.0',
#    '21.8',
#    '84.7',
#    '6.0',
#    '88.6',
#    '11.4',
#    '78.1',
#    '8.0',
#    '84.0',
#    '1.0',
#    '84.0',
#    '0.7',
#    '77.5',
#    '0.1'],
#   ['Cardinals',
#    '8.5',
#    '-5.6',
#    '2.9',
#    '0.5',
#    '1.9',
#    '-0.9',
#    '0.9',
#    '0.87',
#    '-1.34',
#    '2.53',
#    '0.22',
#    '1.26',
#    '-4.69',
#    '6.59'],
#   ['Cardinals',
#    '29.8',
#    '71.2',
#    '48.1',
#    '58.8',
#    '85.6',
#    '76.3',
#    '44.1',
#    '60.1',
#    '11.4'],
#   ['Cardinals',
#    '7.7',
#    '-2.5',
#    '3.1',
#    '1.2',
#    '5.3',
#    '4.3',
#    '0.7',
#    '14.9',
#    '25.1',
#    '2.5',
#    '$20.0']],
#  'Matt Carpenter 2014': ['Cardinals',
#   '158',
#   '595',
#   '709',
#   '162',
#   '119',
#   '33',
#   '2',
#   '8',
#   '99',
#   '59',
#   '95',
#   '2',
#   '111',
#   '8',
#   '9',
#   '2',
#   '3',
#   '5',
#   '3',
#   '.272',
#   ['Cardinals',
#    '709',
#    '13.4',
#    '15.7',
#    '0.86',
#    '.272',
#    '.375',
#    '.375',
#    '.750',
#    '.103',
#    '3.7',
#    '.318',
#    '-0.9',
#    '1.7',
#    '-1.0',
#    '92',
#    '15.5',
#    '.339',
#    '117'],
#   ['Cardinals',
#    '.318',
#    '1.16',
#    '23.8',
#    '41.0',
#    '35.2',
#    '3.5',
#    '4.7',
#    '15',
#    '7.5',
#    '4',
#    '57.1',
#    '31.9',
#    '43.4',
#    '24.7',
#    '15.0',
#    '51.7',
#    '33.3'],
#   ['Cardinals',
#    '2.82',
#    '-9.57',
#    '12.39',
#    '26.52',
#    '2.99',
#    '0.95',
#    '0.84',
#    '2',
#    '1.73',
#    '1.24'],
#   ['Cardinals',
#    '65.1',
#    '91.7',
#    '10.6',
#    '83.8',
#    '6.7',
#    '87.1',
#    '9.4',
#    '76.9',
#    '7.1',
#    '83.5',
#    '1.1',
#    '82.6',
#    '',
#    '',
#    '',
#    '',
#    '0.3'],
#   ['Cardinals',
#    '15.9',
#    '1.8',
#    '-1.8',
#    '1.2',
#    '5.3',
#    '-0.9',
#    '',
#    '',
#    '0.79',
#    '0.54',
#    '-0.86',
#    '0.40',
#    '2.42',
#    '-2.48',
#    '',
#    ''],
#   ['Cardinals',
#    '19.0',
#    '49.4',
#    '32.8',
#    '79.5',
#    '94.8',
#    '89.9',
#    '45.3',
#    '57.7',
#    '3.3'],
#   ['Cardinals',
#    '13.4',
#    '-0.2',
#    '-5.7',
#    '2.2',
#    '13.2',
#    '-3.5',
#    '1.4',
#    '20.0',
#    '31.1',
#    '3.4',
#    '$25.9']],
#  'Alex Rodriguez 2012': ['Yankees',
#   '122',
#   '463',
#   '529',
#   '126',
#   '90',
#   '17',
#   '1',
#   '18',
#   '74',
#   '57',
#   '51',
#   '3',
#   '116',
#   '10',
#   '5',
#   '0',
#   '13',
#   '13',
#   '1',
#   '.272',
#   ['Yankees',
#    '529',
#    '9.6',
#    '21.9',
#    '0.44',
#    '.272',
#    '.353',
#    '.430',
#    '.783',
#    '.158',
#    '5.1',
#    '.323',
#    '-0.6',
#    '0.1',
#    '1.5',
#    '72',
#    '11.5',
#    '.342',
#    '113'],
#   ['Yankees',
#    '.323',
#    '1.39',
#    '22.2',
#    '45.3',
#    '32.5',
#    '9.6',
#    '15.8',
#    '7',
#    '4.4',
#    '1',
#    '100.0',
#    '36.1',
#    '41.2',
#    '22.7',
#    '15.3',
#    '51.7',
#    '33.0'],
#   ['Yankees',
#    '0.30',
#    '-9.07',
#    '9.37',
#    '2.96',
#    '0.36',
#    '1.01',
#    '1.27',
#    '3',
#    '0.80',
#    '-0.51'],
#   ['Yankees',
#    '57.2',
#    '92.4',
#    '13.3',
#    '83.7',
#    '7.8',
#    '88.8',
#    '9.5',
#    '78.6',
#    '9.8',
#    '84.2',
#    '1.8',
#    '85.7',
#    '0.6',
#    '78.7',
#    '0.6'],
#   ['Yankees',
#    '10.0',
#    '-2.3',
#    '1.9',
#    '-1.9',
#    '0.9',
#    '0.7',
#    '-0.1',
#    '0.87',
#    '-0.87',
#    '1.19',
#    '-1.01',
#    '0.46',
#    '2.00',
#    '-0.53'],
#   ['Yankees',
#    '30.7',
#    '67.6',
#    '46.0',
#    '66.7',
#    '79.6',
#    '74.5',
#    '41.6',
#    '60.9',
#    '11.7'],
#   ['Yankees',
#    '8.3',
#    '1.0',
#    '-0.6',
#    '-2.9',
#    '9.3',
#    '-3.5',
#    '1.8',
#    '15.6',
#    '23.3',
#    '2.4',
#    '$15.8']],
#  'Mike Moustakas 2017': ['Royals',
#   '148',
#   '555',
#   '598',
#   '151',
#   '89',
#   '24',
#   '0',
#   '38',
#   '75',
#   '85',
#   '34',
#   '7',
#   '94',
#   '3',
#   '6',
#   '0',
#   '18',
#   '0',
#   '0',
#   '.272',
#   ['Royals',
#    '598',
#    '5.7',
#    '15.7',
#    '0.36',
#    '.272',
#    '.314',
#    '.521',
#    '.835',
#    '.249',
#    '1.1',
#    '.263',
#    '-3.2',
#    '-1.9',
#    '-0.3',
#    '85',
#    '12.0',
#    '.345',
#    '114'],
#   ['Royals',
#    '.263',
#    '0.76',
#    '19.5',
#    '34.8',
#    '45.7',
#    '16.0',
#    '17.8',
#    '7',
#    '4.3',
#    '1',
#    '100.0',
#    '43.7',
#    '33.0',
#    '23.3',
#    '21.2',
#    '46.9',
#    '31.9'],
#   ['Royals',
#    '0.67',
#    '-10.26',
#    '10.93',
#    '8.50',
#    '0.89',
#    '0.91',
#    '2.70',
#    '4',
#    '0.84',
#    '-0.10'],
#   ['Royals',
#    '48.6',
#    '92.6',
#    '15.9',
#    '83.8',
#    '6.1',
#    '88.2',
#    '15.0',
#    '78.3',
#    '12.4',
#    '84.8',
#    '2.0',
#    '83.4',
#    '',
#    '',
#    '',
#    '',
#    '1.2'],
#   ['Royals',
#    '-0.2',
#    '-0.6',
#    '-1.5',
#    '-0.9',
#    '9.0',
#    '0.7',
#    '',
#    '',
#    '-0.02',
#    '-0.16',
#    '-1.06',
#    '-0.28',
#    '3.25',
#    '1.61',
#    '',
#    ''],
#   ['Royals',
#    '40.3',
#    '76.2',
#    '55.6',
#    '69.1',
#    '89.4',
#    '81.0',
#    '42.6',
#    '58.5',
#    '10.6'],
#   ['Royals',
#    '10.0',
#    '-5.4',
#    '-4.5',
#    '0.0',
#    '4.6',
#    '-4.4',
#    '2.1',
#    '18.5',
#    '20.8',
#    '2.1',
#    '$16.5']],
#  'Nicholas Castellanos 2017': ['Tigers',
#   '157',
#   '614',
#   '665',
#   '167',
#   '95',
#   '36',
#   '10',
#   '26',
#   '73',
#   '101',
#   '41',
#   '0',
#   '142',
#   '5',
#   '5',
#   '0',
#   '12',
#   '4',
#   '5',
#   '.272',
#   ['Tigers',
#    '665',
#    '6.2',
#    '21.4',
#    '0.29',
#    '.272',
#    '.320',
#    '.490',
#    '.811',
#    '.218',
#    '4.6',
#    '.313',
#    '0.0',
#    '-0.4',
#    '-1.7',
#    '92',
#    '11.2',
#    '.341',
#    '111'],
#   ['Tigers',
#    '.313',
#    '0.98',
#    '24.5',
#    '37.3',
#    '38.2',
#    '1.6',
#    '14.3',
#    '12',
#    '6.7',
#    '0',
#    '0.0',
#    '38.6',
#    '34.8',
#    '26.6',
#    '11.5',
#    '45.1',
#    '43.4'],
#   ['Tigers',
#    '1.46',
#    '-10.77',
#    '12.23',
#    '22.11',
#    '2.09',
#    '0.93',
#    '3.27',
#    '2',
#    '0.55',
#    '1.01'],
#   ['Tigers',
#    '48.4',
#    '92.9',
#    '21.7',
#    '84.2',
#    '6.4',
#    '88.8',
#    '10.9',
#    '79.6',
#    '10.9',
#    '83.9',
#    '1.4',
#    '84.0',
#    '0.3',
#    '71.8',
#    '',
#    ''],
#   ['Tigers',
#    '11.6',
#    '0.7',
#    '-2.8',
#    '-0.3',
#    '0.2',
#    '1.8',
#    '1.5',
#    '0.92',
#    '0.12',
#    '-1.71',
#    '-0.10',
#    '0.06',
#    '4.99',
#    '18.89'],
#   ['Tigers',
#    '34.6',
#    '73.2',
#    '51.2',
#    '59.2',
#    '83.9',
#    '74.3',
#    '42.9',
#    '63.9',
#    '13.1'],
#   ['Tigers',
#    '8.7',
#    '-2.1',
#    '-15.2',
#    '0.2',
#    '6.7',
#    '-15.0',
#    '2.4',
#    '20.6',
#    '14.6',
#    '1.5',
#    '$11.6']],
#  'Nick Swisher 2012': ['Yankees',
#   '148',
#   '537',
#   '624',
#   '146',
#   '86',
#   '36',
#   '0',
#   '24',
#   '75',
#   '93',
#   '77',
#   '2',
#   '141',
#   '4',
#   '5',
#   '1',
#   '9',
#   '2',
#   '3',
#   '.272',
#   ['Yankees',
#    '624',
#    '12.3',
#    '22.6',
#    '0.55',
#    '.272',
#    '.364',
#    '.473',
#    '.837',
#    '.201',
#    '1.7',
#    '.324',
#    '-0.2',
#    '2.2',
#    '-1.5',
#    '95',
#    '24.0',
#    '.363',
#    '128'],
#   ['Yankees',
#    '.324',
#    '0.99',
#    '22.3',
#    '38.8',
#    '39.0',
#    '9.0',
#    '15.4',
#    '4',
#    '2.6',
#    '0',
#    '0.0',
#    '44.8',
#    '32.3',
#    '22.9',
#    '12.4',
#    '52.2',
#    '35.3'],
#   ['Yankees',
#    '1.85',
#    '-10.51',
#    '12.36',
#    '18.98',
#    '1.98',
#    '0.99',
#    '1.11',
#    '2',
#    '1.21',
#    '0.66'],
#   ['Yankees',
#    '52.5',
#    '92.0',
#    '9.1',
#    '83.0',
#    '8.1',
#    '88.3',
#    '12.2',
#    '77.4',
#    '14.4',
#    '83.9',
#    '3.3',
#    '84.5',
#    '0.6',
#    '77.4',
#    '0.2'],
#   ['Yankees',
#    '14.4',
#    '0.6',
#    '1.9',
#    '-1.1',
#    '6.4',
#    '-1.6',
#    '1.5',
#    '1.04',
#    '0.23',
#    '0.89',
#    '-0.36',
#    '1.67',
#    '-1.86',
#    '9.16'],
#   ['Yankees',
#    '23.8',
#    '66.5',
#    '41.2',
#    '60.5',
#    '84.6',
#    '76.4',
#    '40.6',
#    '52.7',
#    '9.7'],
#   ['Yankees',
#    '20.2',
#    '0.5',
#    '1.1',
#    '-8.2',
#    '20.7',
#    '-7.1',
#    '2.1',
#    '18.4',
#    '34.2',
#    '3.6',
#    '$23.3']],
#  'Jeff Baker 2010': ['Cubs',
#   '79',
#   '206',
#   '224',
#   '56',
#   '37',
#   '13',
#   '2',
#   '4',
#   '29',
#   '21',
#   '16',
#   '0',
#   '50',
#   '1',
#   '1',
#   '0',
#   '6',
#   '1',
#   '0',
#   '.272',
#   ['Cubs',
#    '224',
#    '7.1',
#    '22.3',
#    '0.32',
#    '.272',
#    '.326',
#    '.413',
#    '.739',
#    '.141',
#    '4.8',
#    '.340',
#    '-0.6',
#    '-0.3',
#    '0.0',
#    '27',
#    '0.9',
#    '.326',
#    '97'],
#   ['Cubs',
#    '.340',
#    '1.18',
#    '21.8',
#    '42.3',
#    '35.9',
#    '5.4',
#    '7.1',
#    '2',
#    '3.0',
#    '0',
#    '0.0',
#    '29.9',
#    '37.6',
#    '32.5',
#    '15.9',
#    '56.1',
#    '28.0'],
#   ['Cubs',
#    '0.03',
#    '-3.49',
#    '3.52',
#    '-1.08',
#    '-0.20',
#    '0.90',
#    '1.16',
#    '21',
#    '-0.16',
#    '0.19'],
#   ['Cubs',
#    '55.2',
#    '90.3',
#    '14.5',
#    '82.4',
#    '6.5',
#    '84.9',
#    '10.8',
#    '74.6',
#    '12.3',
#    '80.1',
#    '0.6',
#    '84.4',
#    '',
#    '',
#    '',
#    '',
#    '1.2'],
#   ['Cubs',
#    '4.8',
#    '-4.7',
#    '-0.6',
#    '0.1',
#    '1.6',
#    '-1.1',
#    '',
#    '',
#    '1.00',
#    '-3.79',
#    '-1.10',
#    '0.07',
#    '1.49',
#    '-21.42',
#    '',
#    ''],
#   ['Cubs',
#    '32.0',
#    '71.8',
#    '50.6',
#    '63.3',
#    '89.6',
#    '80.7',
#    '46.6',
#    '61.2',
#    '9.7'],
#   ['Cubs',
#    '-0.9',
#    '-0.9',
#    '4.0',
#    '0.3',
#    '-1.7',
#    '4.3',
#    '0.3',
#    '6.6',
#    '9.6',
#    '1.0',
#    '$6.0']],
#  'Kole Calhoun 2014': ['Angels',
#   '127',
#   '493',
#   '537',
#   '134',
#   '83',
#   '31',
#   '3',
#   '17',
#   '90',
#   '58',
#   '38',
#   '0',
#   '104',
#   '2',
#   '2',
#   '2',
#   '5',
#   '5',
#   '3',
#   '.272',
#   ['Angels',
#    '537',
#    '7.1',
#    '19.4',
#    '0.37',
#    '.272',
#    '.325',
#    '.450',
#    '.776',
#    '.178',
#    '5.2',
#    '.313',
#    '1.8',
#    '0.8',
#    '-0.6',
#    '71',
#    '12.9',
#    '.341',
#    '124'],
#   ['Angels',
#    '.313',
#    '1.35',
#    '23.8',
#    '43.7',
#    '32.5',
#    '9.4',
#    '13.4',
#    '10',
#    '5.8',
#    '0',
#    '0.0',
#    '43.3',
#    '34.9',
#    '21.9',
#    '20.9',
#    '50.1',
#    '29.0'],
#   ['Angels',
#    '2.15',
#    '-8.10',
#    '10.25',
#    '19.98',
#    '2.21',
#    '0.96',
#    '0.82',
#    '10',
#    '1.82',
#    '0.43'],
#   ['Angels',
#    '56.5',
#    '92.1',
#    '11.0',
#    '83.8',
#    '6.7',
#    '88.1',
#    '12.6',
#    '77.4',
#    '10.4',
#    '84.6',
#    '2.3',
#    '83.4',
#    '0.6',
#    '75.1',
#    '0.1'],
#   ['Angels',
#    '18.9',
#    '-3.5',
#    '1.8',
#    '-2.4',
#    '3.1',
#    '1.4',
#    '-0.7',
#    '1.67',
#    '-1.57',
#    '1.38',
#    '-0.94',
#    '1.49',
#    '3.15',
#    '-5.52'],
#   ['Angels',
#    '31.1',
#    '67.6',
#    '46.6',
#    '63.8',
#    '90.6',
#    '80.2',
#    '42.3',
#    '60.5',
#    '9.2'],
#   ['Angels',
#    '14.2',
#    '2.0',
#    '3.0',
#    '-5.4',
#    '16.2',
#    '-2.4',
#    '1.7',
#    '15.2',
#    '30.7',
#    '3.4',
#    '$25.6']],
#  'Ichiro Suzuki 2011': ['Mariners',
#   '161',
#   '677',
#   '721',
#   '184',
#   '154',
#   '22',
#   '3',
#   '5',
#   '80',
#   '47',
#   '39',
#   '13',
#   '69',
#   '0',
#   '4',
#   '1',
#   '11',
#   '40',
#   '7',
#   '.272',
#   ['Mariners',
#    '721',
#    '5.4',
#    '9.6',
#    '0.57',
#    '.272',
#    '.310',
#    '.335',
#    '.645',
#    '.064',
#    '6.0',
#    '.295',
#    '2.7',
#    '-0.3',
#    '4.6',
#    '61',
#    '-20.2',
#    '.281',
#    '79'],
#   ['Mariners',
#    '.295',
#    '2.84',
#    '19.1',
#    '59.9',
#    '21.1',
#    '14.2',
#    '3.9',
#    '36',
#    '10.0',
#    '4',
#    '40.0',
#    '29.9',
#    '39.2',
#    '31.0',
#    '32.3',
#    '55.6',
#    '12.1'],
#   ['Mariners',
#    '-1.79',
#    '-12.38',
#    '10.59',
#    '-10.19',
#    '-1.04',
#    '1.03',
#    '',
#    '',
#    '0',
#    '-1.69',
#    '-0.05'],
#   ['Mariners',
#    '64.1',
#    '91.4',
#    '10.1',
#    '82.4',
#    '6.6',
#    '87.5',
#    '7.8',
#    '77.7',
#    '9.3',
#    '82.6',
#    '1.0',
#    '84.6',
#    '1.2',
#    '65.1',
#    '2.3'],
#   ['Mariners',
#    '-13.6',
#    '-2.9',
#    '-4.2',
#    '5.2',
#    '1.1',
#    '0.8',
#    '1.5',
#    '-0.86',
#    '-1.14',
#    '-2.58',
#    '2.71',
#    '0.47',
#    '3.50',
#    '5.19'],
#   ['Mariners',
#    '35.4',
#    '65.8',
#    '49.0',
#    '85.5',
#    '93.7',
#    '90.4',
#    '44.7',
#    '58.3',
#    '4.6'],
#   ['Mariners',
#    '-18.0',
#    '7.0',
#    '-4.4',
#    '-7.9',
#    '-11.0',
#    '-12.3',
#    '2.3',
#    '21.0',
#    '-0.1',
#    '0.0',
#    '$0.0']],
#  'Wilson Ramos 2013': ['Nationals',
#   '78',
#   '287',
#   '303',
#   '78',
#   '53',
#   '9',
#   '0',
#   '16',
#   '29',
#   '59',
#   '15',
#   '1',
#   '42',
#   '0',
#   '1',
#   '0',
#   '12',
#   '0',
#   '1',
#   '.272',
#   ['Nationals',
#    '303',
#    '5.0',
#    '13.9',
#    '0.36',
#    '.272',
#    '.307',
#    '.470',
#    '.777',
#    '.199',
#    '0.9',
#    '.270',
#    '-3.0',
#    '-2.0',
#    '-0.6',
#    '39',
#    '5.5',
#    '.337',
#    '113'],
#   ['Nationals',
#    '.270',
#    '2.41',
#    '19.5',
#    '56.9',
#    '23.6',
#    '3.4',
#    '27.6',
#    '8',
#    '5.7',
#    '0',
#    '0.0',
#    '36.6',
#    '37.4',
#    '26.0',
#    '12.6',
#    '46.8',
#    '40.7'],
#   ['Nationals',
#    '0.76',
#    '-5.28',
#    '6.04',
#    '14.51',
#    '1.59',
#    '0.99',
#    '0.36',
#    '1',
#    '0.26',
#    '0.50'],
#   ['Nationals',
#    '60.0',
#    '92.5',
#    '17.7',
#    '83.8',
#    '6.7',
#    '87.4',
#    '8.5',
#    '76.8',
#    '6.6',
#    '82.9',
#    '0.6',
#    '83.2',
#    '',
#    '',
#    '',
#    '',
#    '0.4'],
#   ['Nationals',
#    '2.2',
#    '2.0',
#    '0.6',
#    '-1.2',
#    '0.1',
#    '1.0',
#    '',
#    '',
#    '0.36',
#    '1.11',
#    '0.85',
#    '-1.40',
#    '0.15',
#    '16.78',
#    '',
#    ''],
#   ['Nationals',
#    '36.7',
#    '75.1',
#    '53.9',
#    '70.5',
#    '87.3',
#    '81.0',
#    '44.7',
#    '62.1',
#    '10.2'],
#   ['Nationals',
#    '4.5',
#    '-5.6',
#    '0.5',
#    '5.7',
#    '-1.1',
#    '6.2',
#    '0.5',
#    '8.7',
#    '14.2',
#    '1.5',
#    '$11.4']],
#  'Matt Carpenter 2015': ['Cardinals',
#   '154',
#   '574',
#   '665',
#   '156',
#   '81',
#   '44',
#   '3',
#   '28',
#   '101',
#   '84',
#   '81',
#   '5',
#   '151',
#   '6',
#   '4',
#   '0',
#   '5',
#   '4',
#   '3',
#   '.272',
#   ['Cardinals',
#    '665',
#    '12.2',
#    '22.7',
#    '0.54',
#    '.272',
#    '.365',
#    '.505',
#    '.871',
#    '.233',
#    '3.8',
#    '.321',
#    '-0.1',
#    '2.1',
#    '-0.7',
#    '106',
#    '31.4',
#    '.372',
#    '139'],
#   ['Cardinals',
#    '.321',
#    '0.71',
#    '28.5',
#    '29.7',
#    '41.7',
#    '2.3',
#    '15.8',
#    '10',
#    '7.9',
#    '3',
#    '100.0',
#    '39.3',
#    '36.8',
#    '23.9',
#    '11.2',
#    '51.8',
#    '37.0'],
#   ['Cardinals',
#    '5.29',
#    '-10.03',
#    '15.32',
#    '41.37',
#    '4.46',
#    '1.03',
#    '2.43',
#    '3',
#    '3.43',
#    '1.71'],
#   ['Cardinals',
#    '64.1',
#    '91.8',
#    '11.6',
#    '83.7',
#    '6.4',
#    '87.6',
#    '8.9',
#    '77.3',
#    '7.9',
#    '84.1',
#    '1.2',
#    '83.5',
#    '',
#    '',
#    '',
#    '',
#    '0.8'],
#   ['Cardinals',
#    '20.3',
#    '3.9',
#    '2.9',
#    '2.1',
#    '4.6',
#    '0.0',
#    '',
#    '',
#    '1.14',
#    '1.19',
#    '1.61',
#    '0.84',
#    '2.10',
#    '0.14',
#    '',
#    ''],
#   ['Cardinals',
#    '22.5',
#    '60.1',
#    '38.9',
#    '65.9',
#    '87.0',
#    '80.2',
#    '43.8',
#    '61.1',
#    '7.7'],
#   ['Cardinals',
#    '30.6',
#    '1.3',
#    '-4.8',
#    '2.1',
#    '31.9',
#    '-2.6',
#    '1.3',
#    '19.4',
#    '50.0',
#    '5.3',
#    '$42.4']],
#  'Albert Pujols 2014': ['Angels',
#   '159',
#   '633',
#   '695',
#   '172',
#   '106',
#   '37',
#   '1',
#   '28',
#   '89',
#   '105',
#   '48',
#   '11',
#   '71',
#   '5',
#   '9',
#   '0',
#   '28',
#   '5',
#   '1',
#   '.272',
#   ['Angels',
#    '695',
#    '6.9',
#    '10.2',
#    '0.68',
#    '.272',
#    '.324',
#    '.466',
#    '.790',
#    '.194',
#    '3.3',
#    '.265',
#    '-3.3',
#    '-4.0',
#    '0.1',
#    '91',
#    '15.9',
#    '.340',
#    '123'],
#   ['Angels',
#    '.265',
#    '1.29',
#    '18.9',
#    '45.7',
#    '35.4',
#    '12.9',
#    '13.9',
#    '14',
#    '5.4',
#    '0',
#    '0.0',
#    '51.0',
#    '29.8',
#    '19.3',
#    '14.5',
#    '49.4',
#    '36.1'],
#   ['Angels',
#    '3.13',
#    '-11.66',
#    '14.79',
#    '16.50',
#    '1.93',
#    '1.01',
#    '',
#    '',
#    '0',
#    '2.72',
#    '0.37'],
#   ['Angels',
#    '55.8',
#    '92.2',
#    '17.4',
#    '83.9',
#    '7.3',
#    '87.8',
#    '10.3',
#    '78.2',
#    '7.3',
#    '84.4',
#    '1.5',
#    '85.0',
#    '0.5',
#    '74.9',
#    '1.3'],
#   ['Angels',
#    '6.4',
#    '-3.3',
#    '4.5',
#    '1.2',
#    '6.3',
#    '1.0',
#    '-0.6',
#    '0.45',
#    '-0.75',
#    '2.48',
#    '0.48',
#    '3.45',
#    '2.68',
#    '-5.32'],
#   ['Angels',
#    '32.4',
#    '66.6',
#    '47.9',
#    '71.7',
#    '93.7',
#    '85.5',
#    '45.3',
#    '57.1',
#    '6.9'],
#   ['Angels',
#    '17.6',
#    '-7.2',
#    '6.0',
#    '-13.4',
#    '10.4',
#    '-7.3',
#    '2.2',
#    '19.6',
#    '25.0',
#    '2.7',
#    '$20.8']],
#  ...}

# %%
import pickle

with open('master_players_2.pkl', 'wb') as picklefile:
    pickle.dump(master_players, picklefile)

# %%
with open('col_names_list_2.pkl', 'wb') as picklefile:
    pickle.dump(col_names_list, picklefile)
